# %% [markdown]
# # Data Transformation

# %% [markdown]
# In this notebook we'll look at how to transform the input datasets to be consumed into a Data Model.

# %% [markdown]
# ### Step 1 - What inputs do you have?

# %%
# %%bash
# ls ../data
# Out:
# WDICountry.csv
# WDIData.csv
# WDISeries.csv

# %% [markdown]
# ### Step 2 - Get your tools setup

# %% [markdown]
# As part of this we will be using [PySpark](http://spark.apache.org/docs/2.1.1/api/python/index.html) to inspect the data on hand and also gather some basic details.

# %%
import os
from IPython.display import display, HTML
import pandas as pd

#Locating where pyspark is installed
import findspark
findspark.init()
import pyspark

#Settings for PySpark to work
driver_memory = '4g'
num_executors = 2
executor_memory = '1g'
#pyspark_submit_args = ' --driver-memory ' + driver_memory + ' --executor-memory ' + executor_memory + ' --num-executors ' + num_executors + ' pyspark-shell'
pyspark_submit_args = ' --driver-memory ' + driver_memory + ' pyspark-shell'

#Setting the required parameters to start up PySpark
os.environ["PYSPARK_SUBMIT_ARGS"] = pyspark_submit_args

#Import Modules Needed for PySpark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
#Helper for pretty formatting for Spark DataFrames
def showDF(df, limitRows =  20, truncate = True):
    if(truncate):
        pd.set_option('display.max_colwidth', 50)
    else:
        pd.set_option('display.max_colwidth', -1)
    pd.set_option('display.max_rows', limitRows)
    display(df.limit(limitRows).toPandas())
    pd.reset_option('display.max_rows')

# %%
#Creating a spark session
spark = SparkSession.builder.appName("Data Transformation").getOrCreate()

# %% [markdown]
# ### Step 3 - Read the data
#
# We will be using the WDICountry, WDISeries and WDIData files for all the activity below.

# %%
#Read the file into a Spark Data Frame
country = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("../data/WDICountry.csv")

country.count()
# Out:
# 264

# %%
series = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("../data/WDISeries.csv")

series.count()
# Out:
# 1593

# %%
indicators = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("../data/WDIData.csv")

indicators.count()
# Out:
# 420024

# %% [markdown]
# ### Step 4 - Transform the data

# %% [markdown]
# #### Transform the Country Dataset

# %%
countryDim = country \
    .select("2-alpha code", "Country Code", "Short Name", "Long Name", "Region", "Income Group") \
    .withColumnRenamed("2-alpha code", "country_iso_code") \
    .withColumnRenamed("Country Code", "wb_country_code") \
    .withColumnRenamed("Short Name", "country_name") \
    .withColumnRenamed("Long Name", "country_long_name") \
    .withColumnRenamed("Region", "region") \
    .withColumnRenamed("Income Group", "income_group")
    
showDF(countryDim)
# Out:
#    country_iso_code                                    wb_country_code  \
# 0                AW                                                ABW
# 1                AF                                                AFG
# 2                AO                                                AGO
# 3                AL                                                ALB
# 4                AD                                                AND
# 5                1A                                                ARB
# 6                AE                                                ARE
# 7                AR                                                ARG
# 8                AR  The World Bank systematically assesses the app...
# 9                AM                                                ARM
# 10               AS                                                ASM
# 11               AG                                                ATG
# 12               AU                                                AUS
# 13               AT                                                AUT
# 14               AZ                                                AZE
# 15               BI                                                BDI
# 16               BE                                                BEL
# 17               BJ                                                BEN
# 18               BF                                                BFA
# 19               BD                                                BGD
#
#                                          country_name  \
# 0                                               Aruba
# 1                                         Afghanistan
# 2                                              Angola
# 3                                             Albania
# 4                                             Andorra
# 5                                          Arab World
# 6                                United Arab Emirates
# 7                                           Argentina
# 8    the World Bank has found that during 2012-201...
# 9                                             Armenia
# 10                                     American Samoa
# 11                                Antigua and Barbuda
# 12                                          Australia
# 13                                            Austria
# 14                                         Azerbaijan
# 15                                            Burundi
# 16                                            Belgium
# 17                                              Benin
# 18                                       Burkina Faso
# 19                                         Bangladesh
#
#                   country_long_name                             region  \
# 0                             Aruba          Latin America & Caribbean
# 1      Islamic State of Afghanistan                         South Asia
# 2       People's Republic of Angola                 Sub-Saharan Africa
# 3               Republic of Albania              Europe & Central Asia
# 4           Principality of Andorra              Europe & Central Asia
# 5                        Arab World                               None
# 6              United Arab Emirates         Middle East & North Africa
# 7                Argentine Republic                               None
# 8               Upper middle income  Value added at basic prices (VAB)
# 9               Republic of Armenia              Europe & Central Asia
# 10                   American Samoa                East Asia & Pacific
# 11              Antigua and Barbuda          Latin America & Caribbean
# 12        Commonwealth of Australia                East Asia & Pacific
# 13              Republic of Austria              Europe & Central Asia
# 14           Republic of Azerbaijan              Europe & Central Asia
# 15              Republic of Burundi                 Sub-Saharan Africa
# 16               Kingdom of Belgium              Europe & Central Asia
# 17                Republic of Benin                 Sub-Saharan Africa
# 18                     Burkina Faso                 Sub-Saharan Africa
# 19  People's Republic of Bangladesh                         South Asia
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7                  None
# 8                  IBRD
# 9   Lower middle income
# 10  Upper middle income
# 11          High income
# 12          High income
# 13          High income
# 14  Upper middle income
# 15           Low income
# 16          High income
# 17           Low income
# 18           Low income
# 19  Lower middle income

# %% [markdown]
# #### You can also do transformations in sql
# Let's rename the country_name and country_long_name columns

# %%
countryDim.createOrReplaceTempView("country")

# %%
transformQuery = """
select 
    country_iso_code
    , wb_country_code
    , country_name as name
    , country_long_name as long_name
    , region
    , income_group
from 
    country
"""

showDF(spark.sql(transformQuery))
# Out:
#    country_iso_code                                    wb_country_code  \
# 0                AW                                                ABW
# 1                AF                                                AFG
# 2                AO                                                AGO
# 3                AL                                                ALB
# 4                AD                                                AND
# 5                1A                                                ARB
# 6                AE                                                ARE
# 7                AR                                                ARG
# 8                AR  The World Bank systematically assesses the app...
# 9                AM                                                ARM
# 10               AS                                                ASM
# 11               AG                                                ATG
# 12               AU                                                AUS
# 13               AT                                                AUT
# 14               AZ                                                AZE
# 15               BI                                                BDI
# 16               BE                                                BEL
# 17               BJ                                                BEN
# 18               BF                                                BFA
# 19               BD                                                BGD
#
#                                                  name  \
# 0                                               Aruba
# 1                                         Afghanistan
# 2                                              Angola
# 3                                             Albania
# 4                                             Andorra
# 5                                          Arab World
# 6                                United Arab Emirates
# 7                                           Argentina
# 8    the World Bank has found that during 2012-201...
# 9                                             Armenia
# 10                                     American Samoa
# 11                                Antigua and Barbuda
# 12                                          Australia
# 13                                            Austria
# 14                                         Azerbaijan
# 15                                            Burundi
# 16                                            Belgium
# 17                                              Benin
# 18                                       Burkina Faso
# 19                                         Bangladesh
#
#                           long_name                             region  \
# 0                             Aruba          Latin America & Caribbean
# 1      Islamic State of Afghanistan                         South Asia
# 2       People's Republic of Angola                 Sub-Saharan Africa
# 3               Republic of Albania              Europe & Central Asia
# 4           Principality of Andorra              Europe & Central Asia
# 5                        Arab World                               None
# 6              United Arab Emirates         Middle East & North Africa
# 7                Argentine Republic                               None
# 8               Upper middle income  Value added at basic prices (VAB)
# 9               Republic of Armenia              Europe & Central Asia
# 10                   American Samoa                East Asia & Pacific
# 11              Antigua and Barbuda          Latin America & Caribbean
# 12        Commonwealth of Australia                East Asia & Pacific
# 13              Republic of Austria              Europe & Central Asia
# 14           Republic of Azerbaijan              Europe & Central Asia
# 15              Republic of Burundi                 Sub-Saharan Africa
# 16               Kingdom of Belgium              Europe & Central Asia
# 17                Republic of Benin                 Sub-Saharan Africa
# 18                     Burkina Faso                 Sub-Saharan Africa
# 19  People's Republic of Bangladesh                         South Asia
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7                  None
# 8                  IBRD
# 9   Lower middle income
# 10  Upper middle income
# 11          High income
# 12          High income
# 13          High income
# 14  Upper middle income
# 15           Low income
# 16          High income
# 17           Low income
# 18           Low income
# 19  Lower middle income

# %% [markdown]
# ### Step 5 - Check the data quality

# %% [markdown]
# ##### Do all countries have 2 character country_iso_codes ?

# %%
showDF(countryDim.select(col("country_iso_code"), length(col("country_iso_code")).alias("column_length")) \
    .groupBy("column_length").agg(count("*").alias("cnt")).filter("cnt > 1"))
# Out:
#    column_length  cnt
# 0              2  263

# %% [markdown]
# ##### Do we have duplicate records for any of the key columns ?

# %%
showDF(countryDim.groupBy("country_iso_code").agg(count("*").alias("cnt")).filter("cnt > 1"))

showDF(countryDim.groupBy("wb_country_code").agg(count("*").alias("cnt")).filter("cnt > 1"))

showDF(countryDim.groupBy("country_name").agg(count("*").alias("cnt")).filter("cnt > 1"))
# Out:
#   country_iso_code  cnt
# 0               AR    2
# Empty DataFrame
# Columns: [wb_country_code, cnt]
# Index: []
# Empty DataFrame
# Columns: [country_name, cnt]
# Index: []

# %% [markdown]
# ### Step 6 - Fix any issues with data quality

# %%
showDF(countryDim.filter("country_iso_code = 'AR'"))
# Out:
#   country_iso_code                                    wb_country_code  \
# 0               AR                                                ARG
# 1               AR  The World Bank systematically assesses the app...
#
#                                         country_name    country_long_name  \
# 0                                          Argentina   Argentine Republic
# 1   the World Bank has found that during 2012-201...  Upper middle income
#
#                               region income_group
# 0                               None         None
# 1  Value added at basic prices (VAB)         IBRD

# %%
countryDimFinal = countryDim.filter(length(col("wb_country_code")) == 3)

showDF(countryDimFinal)
# Out:
#    country_iso_code wb_country_code          country_name  \
# 0                AW             ABW                 Aruba
# 1                AF             AFG           Afghanistan
# 2                AO             AGO                Angola
# 3                AL             ALB               Albania
# 4                AD             AND               Andorra
# 5                1A             ARB            Arab World
# 6                AE             ARE  United Arab Emirates
# 7                AR             ARG             Argentina
# 8                AM             ARM               Armenia
# 9                AS             ASM        American Samoa
# 10               AG             ATG   Antigua and Barbuda
# 11               AU             AUS             Australia
# 12               AT             AUT               Austria
# 13               AZ             AZE            Azerbaijan
# 14               BI             BDI               Burundi
# 15               BE             BEL               Belgium
# 16               BJ             BEN                 Benin
# 17               BF             BFA          Burkina Faso
# 18               BD             BGD            Bangladesh
# 19               BG             BGR              Bulgaria
#
#                   country_long_name                      region  \
# 0                             Aruba   Latin America & Caribbean
# 1      Islamic State of Afghanistan                  South Asia
# 2       People's Republic of Angola          Sub-Saharan Africa
# 3               Republic of Albania       Europe & Central Asia
# 4           Principality of Andorra       Europe & Central Asia
# 5                        Arab World                        None
# 6              United Arab Emirates  Middle East & North Africa
# 7                Argentine Republic                        None
# 8               Republic of Armenia       Europe & Central Asia
# 9                    American Samoa         East Asia & Pacific
# 10              Antigua and Barbuda   Latin America & Caribbean
# 11        Commonwealth of Australia         East Asia & Pacific
# 12              Republic of Austria       Europe & Central Asia
# 13           Republic of Azerbaijan       Europe & Central Asia
# 14              Republic of Burundi          Sub-Saharan Africa
# 15               Kingdom of Belgium       Europe & Central Asia
# 16                Republic of Benin          Sub-Saharan Africa
# 17                     Burkina Faso          Sub-Saharan Africa
# 18  People's Republic of Bangladesh                  South Asia
# 19             Republic of Bulgaria       Europe & Central Asia
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7                  None
# 8   Lower middle income
# 9   Upper middle income
# 10          High income
# 11          High income
# 12          High income
# 13  Upper middle income
# 14           Low income
# 15          High income
# 16           Low income
# 17           Low income
# 18  Lower middle income
# 19  Upper middle income

# %% [markdown]
# ### Step 7 - Write the data to the destination

# %%
# Here we are going to write the country dimension to an output csv file
countryDimFinal \
    .coalesce(1) \
    .write.csv('../output/CountryDim', mode='overwrite', header='true')

# %% [markdown]
# ### Step 8 - Check if the output was written out as expected

# %%
# %%bash
# cat ../output/CountryDim/*csv | head
# Out:
# country_iso_code,wb_country_code,country_name,country_long_name,region,income_group
# AW,ABW,Aruba,Aruba,Latin America & Caribbean,High income
# AF,AFG,Afghanistan,Islamic State of Afghanistan,South Asia,Low income
# AO,AGO,Angola,People's Republic of Angola,Sub-Saharan Africa,Lower middle income
# AL,ALB,Albania,Republic of Albania,Europe & Central Asia,Upper middle income
# AD,AND,Andorra,Principality of Andorra,Europe & Central Asia,High income
# 1A,ARB,Arab World,Arab World,,
# AE,ARE,United Arab Emirates,United Arab Emirates,Middle East & North Africa,High income
# AR,ARG,Argentina,Argentine Republic,,
# AM,ARM,Armenia,Republic of Armenia,Europe & Central Asia,Lower middle income

# %% [markdown]
# ## Excercise
#
# #### Transform the Series Dataset
# - Filter only for series that have Annual periodicity
# - Get the following columns and rename the selected columns to prepare further processing
#
# | Name in CSV | Column Name |
# | ------------- |:-------------:|
# | Series Code | indicator_code |
# | Indicator Name | indicator_name |
# | Periodicity | periodicity |
# | Aggregation Method | aggregation_method |
#
#
# ##### How many series do you end up with ?

# %%
seriesDim = series \
    .select("Series Code", "Indicator Name", "Short Definition", "Periodicity", "Aggregation Method") \
    .withColumnRenamed("Series Code", "indicator_code") \
    .withColumnRenamed("Indicator Name", "indicator_name") \
    .withColumnRenamed("Periodicity", "periodicity") \
    .withColumnRenamed("Aggregation Method", "aggregation_method") \
    .filter(col("periodicity") == "Annual") 
    
showDF(seriesDim)

seriesDim.count()
# Out:
#        indicator_code                                     indicator_name  \
# 0      AG.AGR.TRAC.NO                   Agricultural machinery, tractors
# 1   AG.CON.FERT.PT.ZS  Fertilizer consumption (% of fertilizer produc...
# 2      AG.CON.FERT.ZS  Fertilizer consumption (kilograms per hectare ...
# 3      AG.LND.AGRI.K2                         Agricultural land (sq. km)
# 4      AG.LND.AGRI.ZS                 Agricultural land (% of land area)
# 5      AG.LND.ARBL.HA                             Arable land (hectares)
# 6   AG.LND.ARBL.HA.PC                  Arable land (hectares per person)
# 7      AG.LND.ARBL.ZS                       Arable land (% of land area)
# 8      AG.LND.CREL.HA            Land under cereal production (hectares)
# 9      AG.LND.CROP.ZS                Permanent cropland (% of land area)
# 10  AG.LND.EL5M.RU.K2  Rural land area where elevation is below 5 met...
# 11  AG.LND.EL5M.RU.ZS  Rural land area where elevation is below 5 met...
# 12  AG.LND.EL5M.UR.K2  Urban land area where elevation is below 5 met...
# 13  AG.LND.EL5M.UR.ZS  Urban land area where elevation is below 5 met...
# 14     AG.LND.EL5M.ZS  Land area where elevation is below 5 meters (%...
# 15     AG.LND.FRST.K2                               Forest area (sq. km)
# 16     AG.LND.FRST.ZS                       Forest area (% of land area)
# 17  AG.LND.IRIG.AG.ZS  Agricultural irrigated land (% of total agricu...
# 18     AG.LND.PRCP.MM       Average precipitation in depth (mm per year)
# 19     AG.LND.TOTL.K2                                 Land area (sq. km)
#
#    Short Definition periodicity aggregation_method
# 0              None      Annual                Sum
# 1              None      Annual   Weighted average
# 2              None      Annual   Weighted average
# 3              None      Annual                Sum
# 4              None      Annual   Weighted average
# 5              None      Annual               None
# 6              None      Annual   Weighted Average
# 7              None      Annual   Weighted average
# 8              None      Annual                Sum
# 9              None      Annual   Weighted average
# 10             None      Annual                Sum
# 11             None      Annual   Weighted Average
# 12             None      Annual                Sum
# 13             None      Annual   Weighted Average
# 14             None      Annual   Weighted Average
# 15             None      Annual                Sum
# 16             None      Annual   Weighted average
# 17             None      Annual   Weighted average
# 18             None      Annual               None
# 19             None      Annual                Sum
# 1587

# %% [markdown]
# #### What data quality checks were you able to perform ?

# %% [markdown]
# - Are there any duplicate codes ?
# - Are all indicator_codes following the same pattern ?
# - Is the case on columns consistent ?

# %% [markdown]
# ### Complex Transformations
# ##### Problem Statement
# We want to measure the cellular and broadband penetration in comparison to the population demographics for every country.  It'll also be helpful to get some insights on annual global aggregates.

# %% [markdown]
# ###### Our dataset has multiple types of metrics.  The only ones that we care about are simple aggregates.

# %%
simpleAggIndicators = seriesDim \
    .filter("lower(aggregation_method) = 'sum'") \
    .select("indicator_code", "indicator_name") \
    .orderBy("indicator_code")

showDF(simpleAggIndicators, limitRows = 500, truncate = False)
# Out:
#            indicator_code  \
# 0    AG.AGR.TRAC.NO
# 1    AG.LND.AGRI.K2
# 2    AG.LND.CREL.HA
# 3    AG.LND.EL5M.RU.K2
# 4    AG.LND.EL5M.UR.K2
# 5    AG.LND.FRST.K2
# 6    AG.LND.TOTL.K2
# 7    AG.LND.TOTL.RU.K2
# 8    AG.LND.TOTL.UR.K2
# 9    AG.PRD.CREL.MT
# 10   AG.SRF.TOTL.K2
# 11   BM.GSR.FCTY.CD
# 12   BM.GSR.ROYL.CD
# 13   BM.KLT.DINV.CD.WD
# 14   BM.TRF.PRVT.CD
# 15   BM.TRF.PWKR.CD.DT
# 16   BX.GRT.EXTA.CD.WD
# 17   BX.GRT.TECH.CD.WD
# 18   BX.GSR.CCIS.CD
# 19   BX.GSR.FCTY.CD
# 20   BX.GSR.ROYL.CD
# 21   BX.KLT.DINV.CD.WD
# 22   BX.KLT.DREM.CD.DT
# 23   BX.PEF.TOTL.CD.WD
# 24   BX.TRF.CURR.CD
# 25   BX.TRF.PWKR.CD
# 26   BX.TRF.PWKR.CD.DT
# 27   CM.MKT.LCAP.CD
# 28   CM.MKT.LDOM.NO
# 29   CM.MKT.TRAD.CD
# 30   DC.DAC.AUSL.CD
# 31   DC.DAC.AUTL.CD
# 32   DC.DAC.BELL.CD
# 33   DC.DAC.CANL.CD
# 34   DC.DAC.CECL.CD
# 35   DC.DAC.CHEL.CD
# 36   DC.DAC.CZEL.CD
# 37   DC.DAC.DEUL.CD
# 38   DC.DAC.DNKL.CD
# 39   DC.DAC.ESPL.CD
# 40   DC.DAC.FINL.CD
# 41   DC.DAC.FRAL.CD
# 42   DC.DAC.GBRL.CD
# 43   DC.DAC.GRCL.CD
# 44   DC.DAC.IRLL.CD
# 45   DC.DAC.ISLL.CD
# 46   DC.DAC.ITAL.CD
# 47   DC.DAC.JPNL.CD
# 48   DC.DAC.KORL.CD
# 49   DC.DAC.LUXL.CD
# 50   DC.DAC.NLDL.CD
# 51   DC.DAC.NORL.CD
# 52   DC.DAC.NZLL.CD
# 53   DC.DAC.POLL.CD
# 54   DC.DAC.PRTL.CD
# 55   DC.DAC.SVKL.CD
# 56   DC.DAC.SVNL.CD
# 57   DC.DAC.SWEL.CD
# 58   DC.DAC.TOTL.CD
# 59   DC.DAC.USAL.CD
# 60   DT.AMT.BLAT.CD
# 61   DT.AMT.BLTC.CD
# 62   DT.AMT.DIMF.CD
# 63   DT.AMT.DLTF.CD
# 64   DT.AMT.DLXF.CD
# 65   DT.AMT.DPNG.CD
# 66   DT.AMT.DPPG.CD
# 67   DT.AMT.MIBR.CD
# 68   DT.AMT.MIDA.CD
# 69   DT.AMT.MLAT.CD
# 70   DT.AMT.MLTC.CD
# 71   DT.AMT.OFFT.CD
# 72   DT.AMT.PBND.CD
# 73   DT.AMT.PCBK.CD
# 74   DT.AMT.PNGB.CD
# 75   DT.AMT.PNGC.CD
# 76   DT.AMT.PROP.CD
# 77   DT.AMT.PRVT.CD
# 78   DT.AXA.DPPG.CD
# 79   DT.AXA.OFFT.CD
# 80   DT.AXA.PRVT.CD
# 81   DT.AXF.DPPG.CD
# 82   DT.AXR.DPPG.CD
# 83   DT.AXR.OFFT.CD
# 84   DT.AXR.PRVT.CD
# 85   DT.COM.DPPG.CD
# 86   DT.COM.MIBR.CD
# 87   DT.COM.MIDA.CD
# 88   DT.COM.OFFT.CD
# 89   DT.COM.PRVT.CD
# 90   DT.DFR.DPPG.CD
# 91   DT.DIS.BLAT.CD
# 92   DT.DIS.BLTC.CD
# 93   DT.DIS.DIMF.CD
# 94   DT.DIS.DLTF.CD
# 95   DT.DIS.DLXF.CD
# 96   DT.DIS.DPNG.CD
# 97   DT.DIS.DPPG.CD
# 98   DT.DIS.IDAG.CD
# 99   DT.DIS.MIBR.CD
# 100  DT.DIS.MIDA.CD
# 101  DT.DIS.MLAT.CD
# 102  DT.DIS.MLTC.CD
# 103  DT.DIS.OFFT.CD
# 104  DT.DIS.PBND.CD
# 105  DT.DIS.PCBK.CD
# 106  DT.DIS.PNGB.CD
# 107  DT.DIS.PNGC.CD
# 108  DT.DIS.PROP.CD
# 109  DT.DIS.PRVT.CD
# 110  DT.DOD.ALLC.CD
# 111  DT.DOD.BLAT.CD
# 112  DT.DOD.BLTC.CD
# 113  DT.DOD.DECT.CD
# 114  DT.DOD.DECT.CD.CG
# 115  DT.DOD.DIMF.CD
# 116  DT.DOD.DLXF.CD
# 117  DT.DOD.DPNG.CD
# 118  DT.DOD.DPPG.CD
# 119  DT.DOD.DSTC.CD
# 120  DT.DOD.MDRI.CD
# 121  DT.DOD.MIBR.CD
# 122  DT.DOD.MIDA.CD
# 123  DT.DOD.MLAT.CD
# 124  DT.DOD.MLTC.CD
# 125  DT.DOD.MWBG.CD
# 126  DT.DOD.OFFT.CD
# 127  DT.DOD.PBND.CD
# 128  DT.DOD.PCBK.CD
# 129  DT.DOD.PNGB.CD
# 130  DT.DOD.PNGC.CD
# 131  DT.DOD.PROP.CD
# 132  DT.DOD.PRVS.CD
# 133  DT.DOD.PRVT.CD
# 134  DT.DOD.PUBS.CD
# 135  DT.DOD.PVLX.CD
# 136  DT.DOD.RSDL.CD
# 137  DT.DOD.VTOT.CD
# 138  DT.DSB.DPPG.CD
# 139  DT.DSF.DPPG.CD
# 140  DT.DXR.DPPG.CD
# 141  DT.INT.BLAT.CD
# 142  DT.INT.BLTC.CD
# 143  DT.INT.DECT.CD
# 144  DT.INT.DIMF.CD
# 145  DT.INT.DLXF.CD
# 146  DT.INT.DPNG.CD
# 147  DT.INT.DPPG.CD
# 148  DT.INT.DSTC.CD
# 149  DT.INT.MIBR.CD
# 150  DT.INT.MIDA.CD
# 151  DT.INT.MLAT.CD
# 152  DT.INT.MLTC.CD
# 153  DT.INT.OFFT.CD
# 154  DT.INT.PBND.CD
# 155  DT.INT.PCBK.CD
# 156  DT.INT.PNGB.CD
# 157  DT.INT.PNGC.CD
# 158  DT.INT.PROP.CD
# 159  DT.INT.PRVT.CD
# 160  DT.IXA.DPPG.CD
# 161  DT.IXA.DPPG.CD.CG
# 162  DT.IXA.OFFT.CD
# 163  DT.IXA.PRVT.CD
# 164  DT.IXF.DPPG.CD
# 165  DT.IXR.DPPG.CD
# 166  DT.IXR.OFFT.CD
# 167  DT.IXR.PRVT.CD
# 168  DT.NFL.BLAT.CD
# 169  DT.NFL.BLTC.CD
# 170  DT.NFL.BOND.CD
# 171  DT.NFL.DECT.CD
# 172  DT.NFL.DLXF.CD
# 173  DT.NFL.DPNG.CD
# 174  DT.NFL.DPPG.CD
# 175  DT.NFL.DSTC.CD
# 176  DT.NFL.FAOG.CD
# 177  DT.NFL.IAEA.CD
# 178  DT.NFL.IFAD.CD
# 179  DT.NFL.ILOG.CD
# 180  DT.NFL.IMFC.CD
# 181  DT.NFL.IMFN.CD
# 182  DT.NFL.MIBR.CD
# 183  DT.NFL.MIDA.CD
# 184  DT.NFL.MLAT.CD
# 185  DT.NFL.MLTC.CD
# 186  DT.NFL.MOTH.CD
# 187  DT.NFL.NEBR.CD
# 188  DT.NFL.NIFC.CD
# 189  DT.NFL.OFFT.CD
# 190  DT.NFL.PBND.CD
# 191  DT.NFL.PCBK.CD
# 192  DT.NFL.PCBO.CD
# 193  DT.NFL.PNGB.CD
# 194  DT.NFL.PNGC.CD
# 195  DT.NFL.PROP.CD
# 196  DT.NFL.PRVT.CD
# 197  DT.NFL.RDBC.CD
# 198  DT.NFL.RDBN.CD
# 199  DT.NFL.UNAI.CD
# 200  DT.NFL.UNCF.CD
# 201  DT.NFL.UNCR.CD
# 202  DT.NFL.UNDP.CD
# 203  DT.NFL.UNEC.CD
# 204  DT.NFL.UNFP.CD
# 205  DT.NFL.UNPB.CD
# 206  DT.NFL.UNRW.CD
# 207  DT.NFL.UNTA.CD
# 208  DT.NFL.WFPG.CD
# 209  DT.NFL.WHOL.CD
# 210  DT.NTR.BLAT.CD
# 211  DT.NTR.BLTC.CD
# 212  DT.NTR.DECT.CD
# 213  DT.NTR.DLXF.CD
# 214  DT.NTR.DPNG.CD
# 215  DT.NTR.DPPG.CD
# 216  DT.NTR.MIBR.CD
# 217  DT.NTR.MIDA.CD
# 218  DT.NTR.MLAT.CD
# 219  DT.NTR.MLTC.CD
# 220  DT.NTR.OFFT.CD
# 221  DT.NTR.PBND.CD
# 222  DT.NTR.PCBK.CD
# 223  DT.NTR.PNGB.CD
# 224  DT.NTR.PNGC.CD
# 225  DT.NTR.PROP.CD
# 226  DT.NTR.PRVT.CD
# 227  DT.ODA.ALLD.CD
# 228  DT.ODA.ALLD.KD
# 229  DT.ODA.OATL.CD
# 230  DT.ODA.OATL.KD
# 231  DT.ODA.ODAT.CD
# 232  DT.ODA.ODAT.KD
# 233  DT.TDS.BLAT.CD
# 234  DT.TDS.BLTC.CD
# 235  DT.TDS.DECT.CD
# 236  DT.TDS.DIMF.CD
# 237  DT.TDS.DLXF.CD
# 238  DT.TDS.DPNG.CD
# 239  DT.TDS.DPPG.CD
# 240  DT.TDS.MIBR.CD
# 241  DT.TDS.MIDA.CD
# 242  DT.TDS.MLAT.CD
# 243  DT.TDS.MLTC.CD
# 244  DT.TDS.OFFT.CD
# 245  DT.TDS.PBND.CD
# 246  DT.TDS.PCBK.CD
# 247  DT.TDS.PNGB.CD
# 248  DT.TDS.PNGC.CD
# 249  DT.TDS.PROP.CD
# 250  DT.TDS.PRVT.CD
# 251  DT.TXR.DPPG.CD
# 252  DT.UND.DPPG.CD
# 253  DT.UND.OFFT.CD
# 254  DT.UND.PRVT.CD
# 255  EG.ELC.RNWX.KH
# 256  EN.ATM.GHGO.KT.CE
# 257  EN.ATM.GHGT.KT.CE
# 258  EN.ATM.METH.AG.KT.CE
# 259  EN.ATM.METH.EG.KT.CE
# 260  EN.ATM.METH.KT.CE
# 261  EN.ATM.NOXE.AG.KT.CE
# 262  EN.ATM.NOXE.EG.KT.CE
# 263  EN.ATM.NOXE.KT.CE
# 264  EN.BIR.THRD.NO
# 265  EN.FSH.THRD.NO
# 266  EN.HPT.THRD.NO
# 267  EN.MAM.THRD.NO
# 268  ER.FSH.AQUA.MT
# 269  ER.FSH.CAPT.MT
# 270  ER.FSH.PROD.MT
# 271  ER.H2O.FWTL.K3
# 272  ER.H2O.INTR.K3
# 273  IE.PPI.ENGY.CD
# 274  IE.PPI.ICTI.CD
# 275  IE.PPI.TELE.CD
# 276  IE.PPI.TRAN.CD
# 277  IE.PPI.WATR.CD
# 278  IE.PPN.ENGY.CD
# 279  IE.PPN.ICTI.CD
# 280  IE.PPN.TELE.CD
# 281  IE.PPN.TRAN.CD
# 282  IE.PPN.WATR.CD
# 283  IP.IDS.NRCT
# 284  IP.IDS.RSCT
# 285  IP.PAT.NRES
# 286  IP.PAT.RESD
# 287  IP.TMK.NRCT
# 288  IP.TMK.NRES
# 289  IP.TMK.RESD
# 290  IP.TMK.RSCT
# 291  IP.TMK.TOTL
# 292  IS.AIR.DPRT
# 293  IS.AIR.GOOD.MT.K1
# 294  IS.AIR.PSGR
# 295  IS.RRS.TOTL.KM
# 296  IS.SHP.GOOD.TU
# 297  IT.CEL.SETS
# 298  IT.MLT.MAIN
# 299  IT.NET.BBND
# 300  IT.NET.SECR
# 301  MS.MIL.MPRT.KD
# 302  MS.MIL.TOTL.P1
# 303  MS.MIL.XPRT.KD
# 304  SE.PRM.ENRL
# 305  SE.PRM.TCHR
# 306  SE.PRM.UNER
# 307  SE.PRM.UNER.FE
# 308  SE.PRM.UNER.MA
# 309  SE.SEC.ENRL
# 310  SE.SEC.ENRL.GC
# 311  SE.SEC.ENRL.VO
# 312  SE.SEC.TCHR
# 313  SE.SEC.TCHR.FE
# 314  SH.DTH.0514
# 315  SH.DTH.IMRT
# 316  SH.DTH.MORT
# 317  SH.DTH.NMRT
# 318  SH.MMR.DTHS
# 319  SH.UHC.NOP1.TO
# 320  SH.UHC.NOP2.TO
# 321  SH.UHC.OOPC.10.TO
# 322  SH.UHC.OOPC.25.TO
# 323  SL.TLF.TOTL.IN
# 324  SM.POP.NETM
# 325  SM.POP.REFG
# 326  SM.POP.REFG.OR
# 327  SM.POP.TOTL
# 328  SP.POP.0014.FE.IN
# 329  SP.POP.0014.MA.IN
# 330  SP.POP.0014.TO
# 331  SP.POP.1564.FE.IN
# 332  SP.POP.1564.MA.IN
# 333  SP.POP.1564.TO
# 334  SP.POP.65UP.FE.IN
# 335  SP.POP.65UP.MA.IN
# 336  SP.POP.65UP.TO
# 337  SP.POP.TOTL
# 338  SP.POP.TOTL.FE.IN
# 339  SP.POP.TOTL.MA.IN
# 340  SP.RUR.TOTL
# 341  SP.URB.TOTL
# 342  TM.VAL.MRCH.WL.CD
# 343  TX.VAL.MRCH.WL.CD
# 344  TX.VAL.TECH.CD
# 345  VC.BTL.DETH
# 346  VC.IDP.NWCV
# 347  VC.IDP.NWDS
# 348  VC.IDP.TOCV
# 349  VC.PKP.TOTL.UN
#
#                                                                                                           indicator_name
# 0    Agricultural machinery, tractors
# 1    Agricultural land (sq. km)
# 2    Land under cereal production (hectares)
# 3    Rural land area where elevation is below 5 meters (sq. km)
# 4    Urban land area where elevation is below 5 meters (sq. km)
# 5    Forest area (sq. km)
# 6    Land area (sq. km)
# 7    Rural land area (sq. km)
# 8    Urban land area (sq. km)
# 9    Cereal production (metric tons)
# 10   Surface area (sq. km)
# 11   Primary income payments (BoP, current US$)
# 12   Charges for the use of intellectual property, payments (BoP, current US$)
# 13   Foreign direct investment, net outflows (BoP, current US$)
# 14   Secondary income, other sectors, payments (BoP, current US$)
# 15   Personal remittances, paid (current US$)
# 16   Grants, excluding technical cooperation (BoP, current US$)
# 17   Technical cooperation grants (BoP, current US$)
# 18   ICT service exports (BoP, current US$)
# 19   Primary income receipts (BoP, current US$)
# 20   Charges for the use of intellectual property, receipts (BoP, current US$)
# 21   Foreign direct investment, net inflows (BoP, current US$)
# 22   Primary income on FDI (current US$)
# 23   Portfolio equity, net inflows (BoP, current US$)
# 24   Secondary income receipts (BoP, current US$)
# 25   Personal transfers, receipts (BoP, current US$)
# 26   Personal remittances, received (current US$)
# 27   Market capitalization of listed domestic companies (current US$)
# 28   Listed domestic companies, total
# 29   Stocks traded, total value (current US$)
# 30   Net bilateral aid flows from DAC donors, Australia (current US$)
# 31   Net bilateral aid flows from DAC donors, Austria (current US$)
# 32   Net bilateral aid flows from DAC donors, Belgium (current US$)
# 33   Net bilateral aid flows from DAC donors, Canada (current US$)
# 34   Net bilateral aid flows from DAC donors, European Union institutions (current US$)
# 35   Net bilateral aid flows from DAC donors, Switzerland (current US$)
# 36   Net bilateral aid flows from DAC donors, Czech Republic (current US$)
# 37   Net bilateral aid flows from DAC donors, Germany (current US$)
# 38   Net bilateral aid flows from DAC donors, Denmark (current US$)
# 39   Net bilateral aid flows from DAC donors, Spain (current US$)
# 40   Net bilateral aid flows from DAC donors, Finland (current US$)
# 41   Net bilateral aid flows from DAC donors, France (current US$)
# 42   Net bilateral aid flows from DAC donors, United Kingdom (current US$)
# 43   Net bilateral aid flows from DAC donors, Greece (current US$)
# 44   Net bilateral aid flows from DAC donors, Ireland (current US$)
# 45   Net bilateral aid flows from DAC donors, Iceland (current US$)
# 46   Net bilateral aid flows from DAC donors, Italy (current US$)
# 47   Net bilateral aid flows from DAC donors, Japan (current US$)
# 48   Net bilateral aid flows from DAC donors, Korea, Rep. (current US$)
# 49   Net bilateral aid flows from DAC donors, Luxembourg (current US$)
# 50   Net bilateral aid flows from DAC donors, Netherlands (current US$)
# 51   Net bilateral aid flows from DAC donors, Norway (current US$)
# 52   Net bilateral aid flows from DAC donors, New Zealand (current US$)
# 53   Net bilateral aid flows from DAC donors, Poland (current US$)
# 54   Net bilateral aid flows from DAC donors, Portugal (current US$)
# 55   Net bilateral aid flows from DAC donors, Slovak Republic (current US$)
# 56   Net bilateral aid flows from DAC donors, Slovenia (current US$)
# 57   Net bilateral aid flows from DAC donors, Sweden (current US$)
# 58   Net bilateral aid flows from DAC donors, Total (current US$)
# 59   Net bilateral aid flows from DAC donors, United States (current US$)
# 60   PPG, bilateral (AMT, current US$)
# 61   PPG, bilateral concessional (AMT, current US$)
# 62   IMF repurchases (AMT, current US$)
# 63   Principal repayments on external debt, long-term + IMF (AMT, current US$)
# 64   Principal repayments on external debt, long-term (AMT, current US$)
# 65   Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)
# 66   Principal repayments on external debt, public and publicly guaranteed (PPG) (AMT, current US$)
# 67   PPG, IBRD (AMT, current US$)
# 68   PPG, IDA (AMT, current US$)
# 69   PPG, multilateral (AMT, current US$)
# 70   PPG, multilateral concessional (AMT, current US$)
# 71   PPG, official creditors (AMT, current US$)
# 72   PPG, bonds (AMT, current US$)
# 73   PPG, commercial banks (AMT, current US$)
# 74   PNG, bonds (AMT, current US$)
# 75   PNG, commercial banks and other creditors (AMT, current US$)
# 76   PPG, other private creditors (AMT, current US$)
# 77   PPG, private creditors (AMT, current US$)
# 78   Principal arrears, public and publicly guaranteed (current US$)
# 79   Principal arrears, official creditors (current US$)
# 80   Principal arrears, private creditors (current US$)
# 81   Principal forgiven (current US$)
# 82   Principal rescheduled (current US$)
# 83   Principal rescheduled, official (current US$)
# 84   Principal rescheduled, private (current US$)
# 85   Commitments, public and publicly guaranteed (COM, current US$)
# 86   Commitments, IBRD (COM, current US$)
# 87   Commitments, IDA (COM, current US$)
# 88   Commitments, official creditors (COM, current US$)
# 89   Commitments, private creditors (COM, current US$)
# 90   Debt forgiveness or reduction (current US$)
# 91   PPG, bilateral (DIS, current US$)
# 92   PPG, bilateral concessional (DIS, current US$)
# 93   IMF purchases (DIS, current US$)
# 94   Disbursements on external debt, long-term + IMF (DIS, current US$)
# 95   Disbursements on external debt, long-term (DIS, current US$)
# 96   Disbursements on external debt, private nonguaranteed (PNG) (DIS, current US$)
# 97   Disbursements on external debt, public and publicly guaranteed (PPG) (DIS, current US$)
# 98   IDA grants (current US$)
# 99   PPG, IBRD (DIS, current US$)
# 100  PPG, IDA (DIS, current US$)
# 101  PPG, multilateral (DIS, current US$)
# 102  PPG, multilateral concessional (DIS, current US$)
# 103  PPG, official creditors (DIS, current US$)
# 104  PPG, bonds (DIS, current US$)
# 105  PPG, commercial banks (DIS, current US$)
# 106  PNG, bonds (DIS, current US$)
# 107  PNG, commercial banks and other creditors (DIS, current US$)
# 108  PPG, other private creditors (DIS, current US$)
# 109  PPG, private creditors (DIS, current US$)
# 110  External debt stocks, concessional (DOD, current US$)
# 111  PPG, bilateral (DOD, current US$)
# 112  PPG, bilateral concessional (DOD, current US$)
# 113  External debt stocks, total (DOD, current US$)
# 114  Total change in external debt stocks (current US$)
# 115  Use of IMF credit (DOD, current US$)
# 116  External debt stocks, long-term (DOD, current US$)
# 117  External debt stocks, private nonguaranteed (PNG) (DOD, current US$)
# 118  External debt stocks, public and publicly guaranteed (PPG) (DOD, current US$)
# 119  External debt stocks, short-term (DOD, current US$)
# 120  Debt forgiveness grants (current US$)
# 121  PPG, IBRD (DOD, current US$)
# 122  PPG, IDA (DOD, current US$)
# 123  PPG, multilateral (DOD, current US$)
# 124  PPG, multilateral concessional (DOD, current US$)
# 125  IBRD loans and IDA credits (DOD, current US$)
# 126  PPG, official creditors (DOD, current US$)
# 127  PPG, bonds (DOD, current US$)
# 128  PPG, commercial banks (DOD, current US$)
# 129  PNG, bonds (DOD, current US$)
# 130  PNG, commercial banks and other creditors (DOD, current US$)
# 131  PPG, other private creditors (DOD, current US$)
# 132  External debt stocks, long-term private sector (DOD, current US$)
# 133  PPG, private creditors (DOD, current US$)
# 134  External debt stocks, long-term public sector (DOD, current US$)
# 135  Present value of external debt (current US$)
# 136  Residual, debt stock-flow reconciliation (current US$)
# 137  External debt stocks, variable rate (DOD, current US$)
# 138  Debt buyback (current US$)
# 139  Debt stock reduction (current US$)
# 140  Debt stock rescheduled (current US$)
# 141  PPG, bilateral (INT, current US$)
# 142  PPG, bilateral concessional (INT, current US$)
# 143  Interest payments on external debt, total (INT, current US$)
# 144  IMF charges (INT, current US$)
# 145  Interest payments on external debt, long-term (INT, current US$)
# 146  Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)
# 147  Interest payments on external debt, public and publicly guaranteed (PPG) (INT, current US$)
# 148  Interest payments on external debt, short-term (INT, current US$)
# 149  PPG, IBRD (INT, current US$)
# 150  PPG, IDA (INT, current US$)
# 151  PPG, multilateral (INT, current US$)
# 152  PPG, multilateral concessional (INT, current US$)
# 153  PPG, official creditors (INT, current US$)
# 154  PPG, bonds (INT, current US$)
# 155  PPG, commercial banks (INT, current US$)
# 156  PNG, bonds (INT, current US$)
# 157  PNG, commercial banks and other creditors (INT, current US$)
# 158  PPG, other private creditors (INT, current US$)
# 159  PPG, private creditors (INT, current US$)
# 160  Interest arrears, public and publicly guaranteed (current US$)
# 161  Net change in interest arrears (current US$)
# 162  Interest arrears, official creditors (current US$)
# 163  Interest arrears, private creditors (current US$)
# 164  Interest forgiven (current US$)
# 165  Interest rescheduled (capitalized) (current US$)
# 166  Interest rescheduled, official (current US$)
# 167  Interest rescheduled, private (current US$)
# 168  Net financial flows, bilateral (NFL, current US$)
# 169  PPG, bilateral concessional (NFL, current US$)
# 170  Portfolio investment, bonds (PPG + PNG) (NFL, current US$)
# 171  Net flows on external debt, total (NFL, current US$)
# 172  Net flows on external debt, long-term (NFL, current US$)
# 173  Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)
# 174  Net flows on external debt, public and publicly guaranteed (PPG) (NFL, current US$)
# 175  Net flows on external debt, short-term (NFL, current US$)
# 176  Net official flows from UN agencies, FAO (current US$)
# 177  Net official flows from UN agencies, IAEA (current US$)
# 178  Net official flows from UN agencies, IFAD (current US$)
# 179  Net official flows from UN agencies, ILO (current US$)
# 180  Net financial flows, IMF concessional (NFL, current US$)
# 181  Net financial flows, IMF nonconcessional (NFL, current US$)
# 182  Net financial flows, IBRD (NFL, current US$)
# 183  Net financial flows, IDA (NFL, current US$)
# 184  Net financial flows, multilateral (NFL, current US$)
# 185  PPG, multilateral concessional (NFL, current US$)
# 186  Net financial flows, others (NFL, current US$)
# 187  EBRD, private nonguaranteed (NFL, current US$)
# 188  IFC, private nonguaranteed (NFL, current US$)
# 189  PPG, official creditors (NFL, current US$)
# 190  PPG, bonds (NFL, current US$)
# 191  PPG, commercial banks (NFL, current US$)
# 192  Commercial banks and other lending (PPG + PNG) (NFL, current US$)
# 193  PNG, bonds (NFL, current US$)
# 194  PNG, commercial banks and other creditors (NFL, current US$)
# 195  PPG, other private creditors (NFL, current US$)
# 196  PPG, private creditors (NFL, current US$)
# 197  Net financial flows, RDB concessional (NFL, current US$)
# 198  Net financial flows, RDB nonconcessional (NFL, current US$)
# 199  Net official flows from UN agencies, UNAIDS (current US$)
# 200  Net official flows from UN agencies, UNICEF (current US$)
# 201  Net official flows from UN agencies, UNHCR (current US$)
# 202  Net official flows from UN agencies, UNDP (current US$)
# 203  Net official flows from UN agencies, UNECE (current US$)
# 204  Net official flows from UN agencies, UNFPA (current US$)
# 205  Net official flows from UN agencies, UNPBF (current US$)
# 206  Net official flows from UN agencies, UNRWA (current US$)
# 207  Net official flows from UN agencies, UNTA (current US$)
# 208  Net official flows from UN agencies, WFP (current US$)
# 209  Net official flows from UN agencies, WHO (current US$)
# 210  PPG, bilateral (NTR, current US$)
# 211  PPG, bilateral concessional (NTR, current US$)
# 212  Net transfers on external debt, total (NTR, current US$)
# 213  Net transfers on external debt, long-term (NTR, current US$)
# 214  Net transfers on external debt, private nonguaranteed (PNG) (NTR, current US$)
# 215  Net transfers on external debt, public and publicly guaranteed (PPG) (NTR, current US$)
# 216  PPG, IBRD (NTR, current US$)
# 217  PPG, IDA (NTR, current US$)
# 218  PPG, multilateral (NTR, current US$)
# 219  PPG, multilateral concessional (NTR, current US$)
# 220  PPG, official creditors (NTR, current US$)
# 221  PPG, bonds (NTR, current US$)
# 222  PPG, commercial banks (NTR, current US$)
# 223  PNG, bonds (NTR, current US$)
# 224  PNG, commercial banks and other creditors (NTR, current US$)
# 225  PPG, other private creditors (NTR, current US$)
# 226  PPG, private creditors (NTR, current US$)
# 227  Net official development assistance and official aid received (current US$)
# 228  Net official development assistance and official aid received (constant 2013 US$)
# 229  Net official aid received (current US$)
# 230  Net official aid received (constant 2014 US$)
# 231  Net official development assistance received (current US$)
# 232  Net official development assistance received (constant 2014 US$)
# 233  PPG, bilateral (TDS, current US$)
# 234  PPG, bilateral concessional (TDS, current US$)
# 235  Debt service on external debt, total (TDS, current US$)
# 236  IMF repurchases and charges (TDS, current US$)
# 237  Debt service on external debt, long-term (TDS, current US$)
# 238  Debt service on external debt, private nonguaranteed (PNG) (TDS, current US$)
# 239  Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)
# 240  PPG, IBRD (TDS, current US$)
# 241  PPG, IDA (TDS, current US$)
# 242  Multilateral debt service (TDS, current US$)
# 243  PPG, multilateral concessional (TDS, current US$)
# 244  PPG, official creditors (TDS, current US$)
# 245  PPG, bonds (TDS, current US$)
# 246  PPG, commercial banks (TDS, current US$)
# 247  PNG, bonds (TDS, current US$)
# 248  PNG, commercial banks and other creditors (TDS, current US$)
# 249  PPG, other private creditors (TDS, current US$)
# 250  PPG, private creditors (TDS, current US$)
# 251  Total amount of debt rescheduled (current US$)
# 252  Undisbursed external debt, total (UND, current US$)
# 253  Undisbursed external debt, official creditors (UND, current US$)
# 254  Undisbursed external debt, private creditors (UND, current US$)
# 255  Electricity production from renewable sources, excluding hydroelectric (kWh)
# 256  Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)
# 257  Total greenhouse gas emissions (kt of CO2 equivalent)
# 258  Agricultural methane emissions (thousand metric tons of CO2 equivalent)
# 259  Methane emissions in energy sector (thousand metric tons of CO2 equivalent)
# 260  Methane emissions (kt of CO2 equivalent)
# 261  Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# 262  Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)
# 263  Nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# 264  Bird species, threatened
# 265  Fish species, threatened
# 266  Plant species (higher), threatened
# 267  Mammal species, threatened
# 268  Aquaculture production (metric tons)
# 269  Capture fisheries production (metric tons)
# 270  Total fisheries production (metric tons)
# 271  Annual freshwater withdrawals, total (billion cubic meters)
# 272  Renewable internal freshwater resources, total (billion cubic meters)
# 273  Investment in energy with private participation (current US$)
# 274  Investment in ICT with private participation (current US$)
# 275  Investment in telecoms with private participation (current US$)
# 276  Investment in transport with private participation (current US$)
# 277  Investment in water and sanitation with private participation (current US$)
# 278  Public private partnerships investment in energy (current US$)
# 279  Public private partnerships investment in ICT (current US$)
# 280  Public private partnerships investment in telecom (current US$)
# 281  Public private partnerships investment in transport (current US$)
# 282  Public private partnerships investment in water and sanitation (current US$)
# 283  Industrial design applications, nonresident, by count
# 284  Industrial design applications, resident, by count
# 285  Patent applications, nonresidents
# 286  Patent applications, residents
# 287  Trademark applications, nonresident, by count
# 288  Trademark applications, direct nonresident
# 289  Trademark applications, direct resident
# 290  Trademark applications, resident, by count
# 291  Trademark applications, total
# 292  Air transport, registered carrier departures worldwide
# 293  Air transport, freight (million ton-km)
# 294  Air transport, passengers carried
# 295  Rail lines (total route-km)
# 296  Container port traffic (TEU: 20 foot equivalent units)
# 297  Mobile cellular subscriptions
# 298  Fixed telephone subscriptions
# 299  Fixed broadband subscriptions
# 300  Secure Internet servers
# 301  Arms imports (SIPRI trend indicator values)
# 302  Armed forces personnel, total
# 303  Arms exports (SIPRI trend indicator values)
# 304  Primary education, pupils
# 305  Primary education, teachers
# 306  Children out of school, primary
# 307  Children out of school, primary, female
# 308  Children out of school, primary, male
# 309  Secondary education, pupils
# 310  Secondary education, general pupils
# 311  Secondary education, vocational pupils
# 312  Secondary education, teachers
# 313  Secondary education, teachers, female
# 314  Number of deaths ages 5-14 years
# 315  Number of infant deaths
# 316  Number of under-five deaths
# 317  Number of neonatal deaths
# 318  Number of maternal deaths
# 319  Number of people pushed below the $1.90 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure
# 320  Number of people pushed below the $3.10 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure
# 321  Number of people spending more than 10% of household consumption or income on out-of-pocket health care expenditure
# 322  Number of people spending more than 25% of household consumption or income on out-of-pocket health care expenditure
# 323  Labor force, total
# 324  Net migration
# 325  Refugee population by country or territory of asylum
# 326  Refugee population by country or territory of origin
# 327  International migrant stock, total
# 328  Population ages 0-14, female
# 329  Population ages 0-14, male
# 330  Population ages 0-14, total
# 331  Population ages 15-64, female
# 332  Population ages 15-64, male
# 333  Population ages 15-64, total
# 334  Population ages 65 and above, female
# 335  Population ages 65 and above, male
# 336  Population ages 65 and above, total
# 337  Population, total
# 338  Population, female
# 339  Population, male
# 340  Rural population
# 341  Urban population
# 342  Merchandise imports by the reporting economy (current US$)
# 343  Merchandise exports by the reporting economy (current US$)
# 344  High-technology exports (current US$)
# 345  Battle-related deaths (number of people)
# 346  Internally displaced persons, new displacement associated with conflict and violence (number of cases)
# 347  Internally displaced persons, new displacement associated with disasters (number of cases)
# 348  Internally displaced persons, total displaced by conflict and violence (number of people)
# 349  Presence of peace keepers (number of troops, police, and military observers in mandate)

# %% [markdown]
# ##### Only keep the indicators that are relevant to requirements i.e. Population indicators and Cellular and Broadband penetration

# %%
targetIndicators = simpleAggIndicators \
    .filter("lower(indicator_name) like '%population%total%' " + 
            " or lower(indicator_name) like '%cellular%' " +
            " or lower(indicator_name) like '%broadband%'") \
    .filter("lower(indicator_name) not like '%refugee%'")

showDF(targetIndicators)
# Out:
#    indicator_code                       indicator_name
# 0     IT.CEL.SETS        Mobile cellular subscriptions
# 1     IT.NET.BBND        Fixed broadband subscriptions
# 2  SP.POP.0014.TO          Population ages 0-14, total
# 3  SP.POP.1564.TO         Population ages 15-64, total
# 4  SP.POP.65UP.TO  Population ages 65 and above, total
# 5     SP.POP.TOTL                    Population, total

# %% [markdown]
# ##### Now that we have identified the various indicators of interest, we can continue with getting the metrics for these indicators

# %%
# Keep the columns that are relevant for further transformations
indicatorsData = indicators \
    .withColumnRenamed("Indicator Code", "indicator_code") \
    .withColumnRenamed("Country Code", "wb_country_code") \
    .drop("Indicator Name") \
    .drop("Country Name") \
    .drop("_c62")

# %%
#Keep only the indicators that we care about
targetIndicatorsData = indicatorsData.join(targetIndicators \
                                         , indicatorsData.indicator_code == targetIndicators.indicator_code) \
    .drop(targetIndicators.indicator_code)

# %%
showDF(targetIndicatorsData)
# Out:
#    wb_country_code  indicator_code        1960        1961        1962  \
# 0              ARB     IT.NET.BBND         NaN         NaN         NaN
# 1              ARB     IT.CEL.SETS         0.0         NaN         NaN
# 2              ARB  SP.POP.0014.TO  40064255.0  41518715.0  42987169.0
# 3              ARB  SP.POP.1564.TO  49179481.0  50158016.0  51208328.0
# 4              ARB  SP.POP.65UP.TO   3247196.0   3367766.0   3486797.0
# 5              ARB     SP.POP.TOTL  92490932.0  95044497.0  97682294.0
# 6              CSS     IT.NET.BBND         NaN         NaN         NaN
# 7              CSS     IT.CEL.SETS         0.0         NaN         NaN
# 8              CSS  SP.POP.0014.TO   1766884.0   1816372.0   1864013.0
# 9              CSS  SP.POP.1564.TO   2151060.0   2173846.0   2198714.0
# 10             CSS  SP.POP.65UP.TO    169157.0    175359.0    182071.0
# 11             CSS     SP.POP.TOTL   4198307.0   4277802.0   4357746.0
# 12             CEB     IT.NET.BBND         NaN         NaN         NaN
# 13             CEB     IT.CEL.SETS         0.0         NaN         NaN
# 14             CEB  SP.POP.0014.TO  26671149.0  26778197.0  26720175.0
# 15             CEB  SP.POP.1564.TO  58135954.0  58632303.0  59217989.0
# 16             CEB  SP.POP.65UP.TO   6594481.0   6826616.0   7076728.0
# 17             CEB     SP.POP.TOTL  91401583.0  92237118.0  93014890.0
# 18             EAR     IT.NET.BBND         NaN         NaN         NaN
# 19             EAR     IT.CEL.SETS         0.0         NaN         NaN
#
#            1963         1964         1965         1966         1967  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          0.0          NaN          NaN
# 2    44458639.0   45910606.0   47331020.0   48923976.0   50456294.0
# 3    52348368.0   53610121.0   55012095.0   56343748.0   57859656.0
# 4     3604069.0    3719175.0    3831873.0    3962869.0    4090982.0
# 5   100411076.0  103239902.0  106174988.0  109230593.0  112406932.0
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          0.0          NaN          NaN
# 8     1908732.0    1949651.0    1986537.0    2027526.0    2065067.0
# 9     2225619.0    2253715.0    2281832.0    2303230.0    2324023.0
# 10     189010.0     196024.0     203156.0     208494.0     214011.0
# 11    4436804.0    4513246.0    4585777.0    4653919.0    4718167.0
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          0.0          NaN          NaN
# 14   26558233.0   26353230.0   26092778.0   25734624.0   25508392.0
# 15   59939405.0   60736450.0   61442683.0   62203237.0   63027152.0
# 16    7348113.0    7632919.0    7911606.0    8210773.0    8508040.0
# 17   93845749.0   94722599.0   95447065.0   96148635.0   97043587.0
# 18          NaN          NaN          NaN          NaN          NaN
# 19          NaN          NaN          0.0          NaN          NaN
#
#                    ...                           2009          2010  \
# 0                  ...                   5.845325e+06  7.123797e+06
# 1                  ...                   2.652708e+08  3.122478e+08
# 2                  ...                   1.180752e+08  1.199217e+08
# 3                  ...                   2.156395e+08  2.217716e+08
# 4                  ...                   1.443047e+07  1.481554e+07
# 5                  ...                   3.481451e+08  3.565089e+08
# 6                  ...                   4.341620e+05  4.731380e+05
# 7                  ...                   7.646708e+06  7.935923e+06
# 8                  ...                   1.828309e+06  1.804177e+06
# 9                  ...                   4.477802e+06  4.533534e+06
# 10                 ...                   5.113080e+05  5.235000e+05
# 11                 ...                   6.939534e+06  6.984096e+06
# 12                 ...                   1.676303e+07  1.805184e+07
# 13                 ...                   1.263254e+08  1.282832e+08
# 14                 ...                   1.583863e+07  1.569344e+07
# 15                 ...                   7.339997e+07  7.304396e+07
# 16                 ...                   1.568577e+07  1.580640e+07
# 17                 ...                   1.049244e+08  1.045438e+08
# 18                 ...                   4.202646e+07  4.905381e+07
# 19                 ...                   1.594519e+09  1.980489e+09
#
#             2011          2012          2013          2014          2015  \
# 0   8.570787e+06  1.032359e+07  1.179999e+07  1.383407e+07  1.660445e+07
# 1   3.519580e+08  3.816419e+08  4.077045e+08  4.150294e+08  4.171956e+08
# 2   1.221659e+08  1.246738e+08  1.273441e+08  1.299870e+08  1.324654e+08
# 3   2.274856e+08  2.329511e+08  2.382154e+08  2.434054e+08  2.486149e+08
# 4   1.524433e+07  1.568205e+07  1.614261e+07  1.665064e+07  1.722468e+07
# 5   3.648959e+08  3.733070e+08  3.817021e+08  3.900430e+08  3.983050e+08
# 6   4.982850e+05  6.272510e+05  6.744190e+05  7.533680e+05  8.971340e+05
# 7   7.534114e+06  7.322041e+06  7.738401e+06  7.952805e+06  8.158698e+06
# 8   1.783918e+06  1.761456e+06  1.738418e+06  1.717638e+06  1.700765e+06
# 9   4.585728e+06  4.638828e+06  4.691000e+06  4.739145e+06  4.781112e+06
# 10  5.356520e+05  5.492100e+05  5.639010e+05  5.793790e+05  5.956210e+05
# 11  7.029022e+06  7.074129e+06  7.118888e+06  7.162679e+06  7.204948e+06
# 12  2.020864e+07  2.088233e+07  2.197775e+07  2.271588e+07  2.335264e+07
# 13  1.312328e+08  1.357431e+08  1.379437e+08  1.366668e+08  1.332150e+08
# 14  1.563016e+07  1.555406e+07  1.547474e+07  1.542814e+07  1.542244e+07
# 15  7.251681e+07  7.205201e+07  7.155604e+07  7.100241e+07  7.037545e+07
# 16  1.602707e+07  1.632924e+07  1.668294e+07  1.706563e+07  1.745986e+07
# 17  1.041740e+08  1.039353e+08  1.037137e+08  1.034962e+08  1.032578e+08
# 18  5.949271e+07  6.929925e+07  7.716696e+07  8.621924e+07  9.952776e+07
# 19  2.287218e+09  2.386166e+09  2.532464e+09  2.659775e+09  2.789512e+09
#
#             2016  2017                       indicator_name
# 0   1.852699e+07  None        Fixed broadband subscriptions
# 1   4.123153e+08  None        Mobile cellular subscriptions
# 2   1.350077e+08  None          Population ages 0-14, total
# 3   2.535661e+08  None         Population ages 15-64, total
# 4   1.787893e+07  None  Population ages 65 and above, total
# 5   4.064527e+08  None                    Population, total
# 6   9.818860e+05  None        Fixed broadband subscriptions
# 7   8.487436e+06  None        Mobile cellular subscriptions
# 8   1.687271e+06  None          Population ages 0-14, total
# 9   4.816676e+06  None         Population ages 15-64, total
# 10  6.131610e+05  None  Population ages 65 and above, total
# 11  7.245472e+06  None                    Population, total
# 12  2.410117e+07  None        Fixed broadband subscriptions
# 13  1.316835e+08  None        Mobile cellular subscriptions
# 14  1.534312e+07  None          Population ages 0-14, total
# 15  6.973236e+07  None         Population ages 15-64, total
# 16  1.791584e+07  None  Population ages 65 and above, total
# 17  1.029913e+08  None                    Population, total
# 18  1.112343e+08  None        Fixed broadband subscriptions
# 19  3.009125e+09  None        Mobile cellular subscriptions
#
# [20 rows x 61 columns]

# %% [markdown]
# #### The output that we see currently isn't the most ideal from a modelling perspective.  Ideally we would like every row to look like the output of the following code block in the new dataset that we plan to create.

# %%
indicatorsSample = targetIndicatorsData \
    .select(col("wb_country_code")
            , col("indicator_code")
            , lit("1960").alias("year")
            , col("1960").alias("indicator_value")) \
    .filter("indicator_value >= 0.0")

showDF(indicatorsSample)
# Out:
#    wb_country_code  indicator_code  year  indicator_value
# 0              ARB     IT.CEL.SETS  1960              0.0
# 1              ARB  SP.POP.0014.TO  1960       40064255.0
# 2              ARB  SP.POP.1564.TO  1960       49179481.0
# 3              ARB  SP.POP.65UP.TO  1960        3247196.0
# 4              ARB     SP.POP.TOTL  1960       92490932.0
# 5              CSS     IT.CEL.SETS  1960              0.0
# 6              CSS  SP.POP.0014.TO  1960        1766884.0
# 7              CSS  SP.POP.1564.TO  1960        2151060.0
# 8              CSS  SP.POP.65UP.TO  1960         169157.0
# 9              CSS     SP.POP.TOTL  1960        4198307.0
# 10             CEB     IT.CEL.SETS  1960              0.0
# 11             CEB  SP.POP.0014.TO  1960       26671149.0
# 12             CEB  SP.POP.1564.TO  1960       58135954.0
# 13             CEB  SP.POP.65UP.TO  1960        6594481.0
# 14             CEB     SP.POP.TOTL  1960       91401583.0
# 15             EAR     IT.CEL.SETS  1960              0.0
# 16             EAR  SP.POP.0014.TO  1960      403027249.0
# 17             EAR  SP.POP.1564.TO  1960      543753940.0
# 18             EAR  SP.POP.65UP.TO  1960       32506217.0
# 19             EAR     SP.POP.TOTL  1960      979287407.0

# %% [markdown]
# ##### Let us start by getting the list of years that we have metrics for

# %%
yearList = [x for x in targetIndicatorsData.schema.names \
             if x != 'wb_country_code' and x != 'indicator_code' and x != 'indicator_name'] 

print(yearList)
# Out:
# ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']

# %%
#Cheat for creating a dataframe with no rows 
indicatorsDF = indicatorsSample.filter('1 = 0')

#Iterate through the list of years and store the rows in the DataFrame we created above
for indicatorYear in yearList:
    print("Processing indicators for " + indicatorYear)
    yearIndicatorDF = targetIndicatorsData \
        .select(col("wb_country_code")
                , col("indicator_code")
                , lit(indicatorYear).alias("year")
                , col(indicatorYear).alias("indicator_value")) \
        .filter("indicator_value >= 0")
    indicatorsDF = indicatorsDF.union(yearIndicatorDF)
# Out:
# Processing indicators for 1960
# Processing indicators for 1961
# Processing indicators for 1962
# Processing indicators for 1963
# Processing indicators for 1964
# Processing indicators for 1965
# Processing indicators for 1966
# Processing indicators for 1967
# Processing indicators for 1968
# Processing indicators for 1969
# Processing indicators for 1970
# Processing indicators for 1971
# Processing indicators for 1972
# Processing indicators for 1973
# Processing indicators for 1974
# Processing indicators for 1975
# Processing indicators for 1976
# Processing indicators for 1977
# Processing indicators for 1978
# Processing indicators for 1979
# Processing indicators for 1980
# Processing indicators for 1981
# Processing indicators for 1982
# Processing indicators for 1983
# Processing indicators for 1984
# Processing indicators for 1985
# Processing indicators for 1986
# Processing indicators for 1987
# Processing indicators for 1988
# Processing indicators for 1989
# Processing indicators for 1990
# Processing indicators for 1991
# Processing indicators for 1992
# Processing indicators for 1993
# Processing indicators for 1994
# Processing indicators for 1995
# Processing indicators for 1996
# Processing indicators for 1997
# Processing indicators for 1998
# Processing indicators for 1999
# Processing indicators for 2000
# Processing indicators for 2001
# Processing indicators for 2002
# Processing indicators for 2003
# Processing indicators for 2004
# Processing indicators for 2005
# Processing indicators for 2006
# Processing indicators for 2007
# Processing indicators for 2008
# Processing indicators for 2009
# Processing indicators for 2010
# Processing indicators for 2011
# Processing indicators for 2012
# Processing indicators for 2013
# Processing indicators for 2014
# Processing indicators for 2015
# Processing indicators for 2016
# Processing indicators for 2017

# %% [markdown]
# #### Let's cache the dataset to iterate over it

# %%
indicatorsDF.cache()

#Force the data to be cached
indicatorsDF.count()
# Out:
# 70303

# %%
#Check the indicator counts per year
#showDF(indicatorsDF.groupBy('year').agg(count("*")).orderBy("year"), limitRows=100)

# %% [markdown]
# #### Getting yearly indicator totals

# %%
yearPivot = indicatorsDF.groupBy('year').pivot('indicator_code').sum('indicator_value')

# %%
showDF(yearPivot.orderBy('year'))
# Out:
#     year  IT.CEL.SETS IT.NET.BBND  SP.POP.0014.TO  SP.POP.1564.TO  \
# 0   1960          0.0        None    1.164043e+10    1.764656e+10
# 1   1961          NaN        None    1.186066e+10    1.780707e+10
# 2   1962          NaN        None    1.215358e+10    1.803340e+10
# 3   1963          NaN        None    1.249841e+10    1.834110e+10
# 4   1964          NaN        None    1.281722e+10    1.868178e+10
# 5   1965          0.0        None    1.310455e+10    1.907143e+10
# 6   1966          NaN        None    1.343731e+10    1.943187e+10
# 7   1967          NaN        None    1.371767e+10    1.984342e+10
# 8   1968          NaN        None    1.396924e+10    2.029706e+10
# 9   1969          NaN        None    1.422516e+10    2.078273e+10
# 10  1970          0.0        None    1.449018e+10    2.127209e+10
# 11  1971          NaN        None    1.478645e+10    2.173800e+10
# 12  1972          NaN        None    1.507061e+10    2.221091e+10
# 13  1973          NaN        None    1.534245e+10    2.269287e+10
# 14  1974          NaN        None    1.559221e+10    2.319928e+10
# 15  1975          0.0        None    1.580695e+10    2.372537e+10
# 16  1976          0.0        None    1.601854e+10    2.422892e+10
# 17  1977          0.0        None    1.619743e+10    2.476186e+10
# 18  1978          0.0        None    1.635522e+10    2.533091e+10
# 19  1979          0.0        None    1.650413e+10    2.593300e+10
#
#     SP.POP.65UP.TO   SP.POP.TOTL
# 0     1.419169e+09  3.072052e+10
# 1     1.451321e+09  3.113369e+10
# 2     1.483492e+09  3.168550e+10
# 3     1.517104e+09  3.237204e+10
# 4     1.549219e+09  3.306404e+10
# 5     1.581083e+09  3.377327e+10
# 6     1.634468e+09  3.452025e+10
# 7     1.687816e+09  3.526591e+10
# 8     1.741146e+09  3.602484e+10
# 9     1.795141e+09  3.682082e+10
# 10    1.848060e+09  3.762852e+10
# 11    1.912749e+09  3.845576e+10
# 12    1.975038e+09  3.927555e+10
# 13    2.035301e+09  4.009001e+10
# 14    2.095556e+09  4.090685e+10
# 15    2.155471e+09  4.170800e+10
# 16    2.227452e+09  4.249554e+10
# 17    2.299457e+09  4.327978e+10
# 18    2.369935e+09  4.407752e+10
# 19    2.435092e+09  4.489408e+10

# %%
yearPivot.printSchema()
# Out:
# root
#  |-- year: string (nullable = false)
#  |-- IT.CEL.SETS: double (nullable = true)
#  |-- IT.NET.BBND: double (nullable = true)
#  |-- SP.POP.0014.TO: double (nullable = true)
#  |-- SP.POP.1564.TO: double (nullable = true)
#  |-- SP.POP.65UP.TO: double (nullable = true)
#  |-- SP.POP.TOTL: double (nullable = true)

# %%
yearPivotDF = yearPivot.orderBy('year') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population')

# %% [markdown]
# #### Data Quality Checkpoint

# %%
yearPivotDF.cache()
# Out:
# DataFrame[year: string, cellular_subscriptions: double, broadband_subscriptions: double, population_age_0_to_14: double, population_age_15_64: double, population_age_65_and_above: double, population: double]

# %%
yearPivotDF.filter('population_age_0_to_14 < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_15_64 < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_0_to_14 < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_65_and_above < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('population < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('cellular_subscriptions < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('broadband_subscriptions < 0').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_0_to_14 > population').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_15_64 > population').count()
# Out:
# 0

# %%
yearPivotDF.filter('population_age_65_and_above > population').count()
# Out:
# 0

# %%
yearPivotDF.filter('(population_age_0_to_14 + population_age_15_64 + population_age_65_and_above) > population').count()
# Out:
# 0

# %%
#Write the yearly totals to a CSV File
yearPivotDF \
    .select(col('year')
            , col('population').cast(DecimalType(38, 2))
            , col('population_age_0_to_14').cast(DecimalType(38, 2))
            , col('population_age_15_64').cast(DecimalType(38, 2))
            , col('population_age_65_and_above').cast(DecimalType(38, 2))
            , col('broadband_subscriptions').cast(DecimalType(38, 2))
            , col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('../output/YearlyStats', mode='overwrite', header='true')

# %% [markdown]
# #### Getting yearly regional totals

# %%
regionalIndicators = indicatorsDF.join(countryDimFinal
                                       , indicatorsDF.wb_country_code == countryDim.wb_country_code
                                       , "inner") \
    .select(countryDim.region
            , indicatorsDF.wb_country_code
            , indicatorsDF.year
            , indicatorsDF.indicator_code
            , indicatorsDF.indicator_value)

# %%
showDF(regionalIndicators)
# Out:
#    region wb_country_code  year  indicator_code  indicator_value
# 0    None             ARB  1960     IT.CEL.SETS              0.0
# 1    None             ARB  1960  SP.POP.0014.TO       40064255.0
# 2    None             ARB  1960  SP.POP.1564.TO       49179481.0
# 3    None             ARB  1960  SP.POP.65UP.TO        3247196.0
# 4    None             ARB  1960     SP.POP.TOTL       92490932.0
# 5    None             CSS  1960     IT.CEL.SETS              0.0
# 6    None             CSS  1960  SP.POP.0014.TO        1766884.0
# 7    None             CSS  1960  SP.POP.1564.TO        2151060.0
# 8    None             CSS  1960  SP.POP.65UP.TO         169157.0
# 9    None             CSS  1960     SP.POP.TOTL        4198307.0
# 10   None             CEB  1960     IT.CEL.SETS              0.0
# 11   None             CEB  1960  SP.POP.0014.TO       26671149.0
# 12   None             CEB  1960  SP.POP.1564.TO       58135954.0
# 13   None             CEB  1960  SP.POP.65UP.TO        6594481.0
# 14   None             CEB  1960     SP.POP.TOTL       91401583.0
# 15   None             EAR  1960     IT.CEL.SETS              0.0
# 16   None             EAR  1960  SP.POP.0014.TO      403027249.0
# 17   None             EAR  1960  SP.POP.1564.TO      543753940.0
# 18   None             EAR  1960  SP.POP.65UP.TO       32506217.0
# 19   None             EAR  1960     SP.POP.TOTL      979287407.0

# %%
regionalPivot = regionalIndicators.groupBy('region', 'year').pivot('indicator_code').sum('indicator_value')

# %%
showDF(regionalPivot.orderBy('region', 'year'), limitRows=100)
# Out:
#                  region  year   IT.CEL.SETS   IT.NET.BBND  SP.POP.0014.TO  \
# 0                  None  1960  0.000000e+00           NaN    1.052918e+10
# 1                  None  1961           NaN           NaN    1.072883e+10
# 2                  None  1962           NaN           NaN    1.099508e+10
# 3                  None  1963           NaN           NaN    1.130876e+10
# 4                  None  1964           NaN           NaN    1.159883e+10
# 5                  None  1965  0.000000e+00           NaN    1.186024e+10
# 6                  None  1966           NaN           NaN    1.216311e+10
# 7                  None  1967           NaN           NaN    1.241838e+10
# 8                  None  1968           NaN           NaN    1.264760e+10
# 9                  None  1969           NaN           NaN    1.288063e+10
# 10                 None  1970  0.000000e+00           NaN    1.312208e+10
# 11                 None  1971           NaN           NaN    1.339224e+10
# 12                 None  1972           NaN           NaN    1.365141e+10
# 13                 None  1973           NaN           NaN    1.389953e+10
# 14                 None  1974           NaN           NaN    1.412763e+10
# 15                 None  1975  0.000000e+00           NaN    1.432417e+10
# 16                 None  1976  0.000000e+00           NaN    1.451799e+10
# 17                 None  1977  0.000000e+00           NaN    1.468237e+10
# 18                 None  1978  0.000000e+00           NaN    1.482777e+10
# 19                 None  1979  0.000000e+00           NaN    1.496503e+10
# 20                 None  1980  1.643740e+05           NaN    1.509894e+10
# 21                 None  1981  3.948430e+05           NaN    1.524631e+10
# 22                 None  1982  6.097410e+05           NaN    1.540788e+10
# 23                 None  1983  8.811210e+05           NaN    1.557283e+10
# 24                 None  1984  1.796544e+06           NaN    1.573395e+10
# 25                 None  1985  4.108062e+06           NaN    1.589767e+10
# 26                 None  1986  7.968225e+06           NaN    1.612344e+10
# 27                 None  1987  1.400003e+07           NaN    1.634716e+10
# 28                 None  1988  2.382929e+07           NaN    1.656733e+10
# 29                 None  1989  4.035322e+07           NaN    1.677947e+10
# 30                 None  1990  6.197029e+07           NaN    1.698502e+10
# 31                 None  1991  9.094891e+07           NaN    1.722226e+10
# 32                 None  1992  1.315735e+08           NaN    1.740833e+10
# 33                 None  1993  1.976234e+08           NaN    1.756395e+10
# 34                 None  1994  3.285952e+08           NaN    1.770281e+10
# 35                 None  1995  5.479371e+08           NaN    1.783435e+10
# 36                 None  1996  8.897939e+08           NaN    1.791217e+10
# 37                 None  1997  1.370814e+09           NaN    1.800713e+10
# 38                 None  1998  2.084697e+09  8.459000e+05    1.809512e+10
# 39                 None  1999  3.340473e+09  3.336286e+06    1.814662e+10
# 40                 None  2000  5.256610e+09  6.395584e+07    1.815287e+10
# 41                 None  2001  7.129602e+09  1.901302e+08    1.817975e+10
# 42                 None  2002  8.931245e+09  3.736333e+08    1.816684e+10
# 43                 None  2003  1.118402e+10  6.268839e+08    1.813193e+10
# 44                 None  2004  1.441172e+10  1.021665e+09    1.810561e+10
# 45                 None  2005  1.862753e+10  1.465743e+09    1.810565e+10
# 46                 None  2006  2.378235e+10  1.959475e+09    1.815655e+10
# 47                 None  2007  2.977887e+10  2.494826e+09    1.822321e+10
# 48                 None  2008  3.627309e+10  3.041798e+09    1.831052e+10
# 49                 None  2009  4.216466e+10  3.570759e+09    1.841486e+10
# 50                 None  2010  4.860450e+10  4.077592e+09    1.853275e+10
# 51                 None  2011  5.443422e+10  4.677802e+09    1.867669e+10
# 52                 None  2012  5.823945e+10  5.135903e+09    1.883375e+10
# 53                 None  2013  6.232981e+10  5.523110e+09    1.899938e+10
# 54                 None  2014  6.556419e+10  5.876340e+09    1.916547e+10
# 55                 None  2015  6.735425e+10  6.945989e+09    1.932514e+10
# 56                 None  2016  7.037847e+10  7.685777e+09    1.949220e+10
# 57  East Asia & Pacific  1960  0.000000e+00           NaN    4.028388e+08
# 58  East Asia & Pacific  1961           NaN           NaN    4.048620e+08
# 59  East Asia & Pacific  1962           NaN           NaN    4.135164e+08
# 60  East Asia & Pacific  1963           NaN           NaN    4.274245e+08
# 61  East Asia & Pacific  1964           NaN           NaN    4.399146e+08
# 62  East Asia & Pacific  1965  0.000000e+00           NaN    4.507900e+08
# 63  East Asia & Pacific  1966           NaN           NaN    4.645586e+08
# 64  East Asia & Pacific  1967           NaN           NaN    4.751606e+08
# 65  East Asia & Pacific  1968           NaN           NaN    4.843480e+08
# 66  East Asia & Pacific  1969           NaN           NaN    4.946925e+08
# 67  East Asia & Pacific  1970  0.000000e+00           NaN    5.059325e+08
# 68  East Asia & Pacific  1971           NaN           NaN    5.188175e+08
# 69  East Asia & Pacific  1972           NaN           NaN    5.306244e+08
# 70  East Asia & Pacific  1973           NaN           NaN    5.413568e+08
# 71  East Asia & Pacific  1974           NaN           NaN    5.504325e+08
# 72  East Asia & Pacific  1975  0.000000e+00           NaN    5.563652e+08
# 73  East Asia & Pacific  1976  0.000000e+00           NaN    5.591825e+08
# 74  East Asia & Pacific  1977  0.000000e+00           NaN    5.595765e+08
# 75  East Asia & Pacific  1978  0.000000e+00           NaN    5.581797e+08
# 76  East Asia & Pacific  1979  0.000000e+00           NaN    5.556313e+08
# 77  East Asia & Pacific  1980  0.000000e+00           NaN    5.521305e+08
# 78  East Asia & Pacific  1981  1.327500e+04           NaN    5.468523e+08
# 79  East Asia & Pacific  1982  1.980400e+04           NaN    5.429351e+08
# 80  East Asia & Pacific  1983  2.719800e+04           NaN    5.392658e+08
# 81  East Asia & Pacific  1984  4.314200e+04           NaN    5.352559e+08
# 82  East Asia & Pacific  1985  6.822900e+04           NaN    5.317639e+08
# 83  East Asia & Pacific  1986  1.283900e+05           NaN    5.320735e+08
# 84  East Asia & Pacific  1987  2.262250e+05           NaN    5.330600e+08
# 85  East Asia & Pacific  1988  4.240700e+05           NaN    5.346119e+08
# 86  East Asia & Pacific  1989  8.716370e+05           NaN    5.363774e+08
# 87  East Asia & Pacific  1990  1.563028e+06           NaN    5.379553e+08
# 88  East Asia & Pacific  1991  2.548507e+06           NaN    5.426724e+08
# 89  East Asia & Pacific  1992  3.672393e+06           NaN    5.442749e+08
# 90  East Asia & Pacific  1993  5.491192e+06           NaN    5.441875e+08
# 91  East Asia & Pacific  1994  1.066866e+07           NaN    5.441064e+08
# 92  East Asia & Pacific  1995  2.382787e+07           NaN    5.443942e+08
# 93  East Asia & Pacific  1996  4.831455e+07           NaN    5.395010e+08
# 94  East Asia & Pacific  1997  7.338903e+07           NaN    5.370740e+08
# 95  East Asia & Pacific  1998  1.026377e+08  6.700000e+04    5.349747e+08
# 96  East Asia & Pacific  1999  1.483686e+08  6.104670e+05    5.302994e+08
# 97  East Asia & Pacific  2000  2.169886e+08  5.273154e+06    5.221823e+08
# 98  East Asia & Pacific  2001  3.068284e+08  1.304106e+07    5.144663e+08
# 99  East Asia & Pacific  2002  4.012531e+08  2.481227e+07    5.039071e+08
#
#     SP.POP.1564.TO  SP.POP.65UP.TO   SP.POP.TOTL
# 0     1.591379e+10    1.270274e+09  2.772620e+10
# 1     1.605789e+10    1.299015e+09  2.809895e+10
# 2     1.626195e+10    1.327810e+09  2.859841e+10
# 3     1.653985e+10    1.357916e+09  2.922045e+10
# 4     1.684778e+10    1.386660e+09  2.984755e+10
# 5     1.720040e+10    1.415175e+09  3.049045e+10
# 6     1.752669e+10    1.463169e+09  3.116795e+10
# 7     1.789958e+10    1.511139e+09  3.184446e+10
# 8     1.831104e+10    1.559115e+09  3.253346e+10
# 9     1.875102e+10    1.607638e+09  3.325536e+10
# 10    1.919451e+10    1.655206e+09  3.398822e+10
# 11    1.961622e+10    1.713359e+09  3.473858e+10
# 12    2.004433e+10    1.769368e+09  3.548225e+10
# 13    2.048088e+10    1.823579e+09  3.622150e+10
# 14    2.093920e+10    1.877739e+09  3.696246e+10
# 15    2.141546e+10    1.931593e+09  3.768949e+10
# 16    2.187192e+10    1.996356e+09  3.840491e+10
# 17    2.235479e+10    2.061099e+09  3.911727e+10
# 18    2.287031e+10    2.124448e+09  3.984191e+10
# 19    2.341573e+10    2.183012e+09  4.058354e+10
# 20    2.398095e+10    2.234548e+09  4.133457e+10
# 21    2.454908e+10    2.289441e+09  4.210536e+10
# 22    2.514191e+10    2.336312e+09  4.290702e+10
# 23    2.574546e+10    2.378442e+09  4.371806e+10
# 24    2.635158e+10    2.421065e+09  4.452835e+10
# 25    2.696630e+10    2.468335e+09  4.535450e+10
# 26    2.752951e+10    2.529412e+09  4.620501e+10
# 27    2.811389e+10    2.593288e+09  4.707746e+10
# 28    2.870866e+10    2.659850e+09  4.795944e+10
# 29    2.930921e+10    2.729181e+09  4.884193e+10
# 30    2.992424e+10    2.801850e+09  4.973563e+10
# 31    3.046761e+10    2.884735e+09  5.059958e+10
# 32    3.103902e+10    2.971086e+09  5.144385e+10
# 33    3.164183e+10    3.058809e+09  5.229041e+10
# 34    3.225423e+10    3.143700e+09  5.312697e+10
# 35    3.288001e+10    3.225200e+09  5.396619e+10
# 36    3.353083e+10    3.321436e+09  5.479144e+10
# 37    3.417312e+10    3.410447e+09  5.561804e+10
# 38    3.481837e+10    3.495128e+09  5.643476e+10
# 39    3.549111e+10    3.580861e+09  5.724252e+10
# 40    3.619681e+10    3.669437e+09  5.804240e+10
# 41    3.686679e+10    3.771371e+09  5.884124e+10
# 42    3.757234e+10    3.874756e+09  5.963732e+10
# 43    3.830517e+10    3.977538e+09  6.043808e+10
# 44    3.904122e+10    4.073891e+09  6.124421e+10
# 45    3.976563e+10    4.161611e+09  6.205643e+10
# 46    4.043703e+10    4.256778e+09  6.287409e+10
# 47    4.110453e+10    4.345034e+09  6.369668e+10
# 48    4.176503e+10    4.431800e+09  6.453143e+10
# 49    4.241193e+10    4.523231e+09  6.537427e+10
# 50    4.304161e+10    4.623745e+09  6.622252e+10
# 51    4.362647e+10    4.740515e+09  6.706828e+10
# 52    4.421142e+10    4.865635e+09  6.793559e+10
# 53    4.478932e+10    5.001284e+09  6.881501e+10
# 54    4.535837e+10    5.152544e+09  6.970143e+10
# 55    4.591716e+10    5.322814e+09  7.058997e+10
# 56    4.644686e+10    5.520961e+09  7.148507e+10
# 57    5.863290e+08    4.009996e+07  1.029333e+09
# 58    5.870740e+08    4.052241e+07  1.032525e+09
# 59    5.921018e+08    4.090652e+07  1.046593e+09
# 60    6.030349e+08    4.142506e+07  1.071955e+09
# 61    6.151427e+08    4.182021e+07  1.096951e+09
# 62    6.299228e+08    4.221279e+07  1.123001e+09
# 63    6.438748e+08    4.396782e+07  1.152479e+09
# 64    6.599945e+08    4.576509e+07  1.181000e+09
# 65    6.779085e+08    4.758187e+07  1.209920e+09
# 66    6.980435e+08    4.951662e+07  1.242337e+09
# 67    7.173903e+08    5.134007e+07  1.274749e+09
# 68    7.356724e+08    5.352987e+07  1.308108e+09
# 69    7.533234e+08    5.561427e+07  1.339653e+09
# 70    7.705633e+08    5.761212e+07  1.369626e+09
# 71    7.891777e+08    5.971466e+07  1.399421e+09
# 72    8.079829e+08    6.179528e+07  1.426241e+09
# 73    8.265434e+08    6.431159e+07  1.450137e+09
# 74    8.461550e+08    6.686961e+07  1.472702e+09
# 75    8.674097e+08    6.949443e+07  1.495186e+09
# 76    8.901934e+08    7.215549e+07  1.518085e+09
# 77    9.135261e+08    7.477354e+07  1.540538e+09
# 78    9.390349e+08    7.783798e+07  1.563837e+09
# 79    9.655223e+08    8.085994e+07  1.589435e+09
# 80    9.918753e+08    8.376825e+07  1.615033e+09
# 81    1.017470e+09    8.652520e+07  1.639382e+09
# 82    1.043174e+09    8.923951e+07  1.664314e+09
# 83    1.066584e+09    9.201363e+07  1.690815e+09
# 84    1.090754e+09    9.474759e+07  1.718713e+09
# 85    1.114623e+09    9.747580e+07  1.746868e+09
# 86    1.137562e+09    1.003002e+08  1.774403e+09
# 87    1.159781e+09    1.033325e+08  1.801239e+09
# 88    1.177749e+09    1.064786e+08  1.827076e+09
# 89    1.196868e+09    1.098667e+08  1.851191e+09
# 90    1.216605e+09    1.134781e+08  1.874458e+09
# 91    1.236200e+09    1.172476e+08  1.897745e+09
# 92    1.254962e+09    1.210980e+08  1.920651e+09
# 93    1.277739e+09    1.257523e+08  1.943194e+09
# 94    1.297690e+09    1.301948e+08  1.965166e+09
# 95    1.316589e+09    1.345291e+08  1.986304e+09
# 96    1.336722e+09    1.388495e+08  2.006085e+09
# 97    1.359328e+09    1.432389e+08  2.024966e+09
# 98    1.380717e+09    1.477788e+08  2.043181e+09
# 99    1.404084e+09    1.522803e+08  2.060490e+09

# %%
#Write the regional-yearly totals to a CSV File
regionalPivot.filter('region is not null') \
    .orderBy('region','year') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population') \
    .select(col('region')
            , col('year')
            , col('population').cast(DecimalType(38, 2))
            , col('population_age_0_to_14').cast(DecimalType(38, 2))
            , col('population_age_15_64').cast(DecimalType(38, 2))
            , col('population_age_65_and_above').cast(DecimalType(38, 2))
            , col('broadband_subscriptions').cast(DecimalType(38, 2))
            , col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('../output/RegionalStats', mode='overwrite', header='true')

# %% [markdown]
# ## Short Excercise
#
# Becky finds the regional metrics interesting, but she wants to look at these metrics at a country level for each year.  Can you adapt the regional pivot that we computed earlier to get the metrics for each year and country ?

# %%
countryIndicators = indicatorsDF.join(countryDimFinal
                                       , indicatorsDF.wb_country_code == countryDim.wb_country_code
                                       , "inner") \
    .select(indicatorsDF.wb_country_code
            , countryDim.country_iso_code
            , countryDim.country_name
            , indicatorsDF.year
            , indicatorsDF.indicator_code
            , indicatorsDF.indicator_value)

showDF(countryIndicators)
# Out:
#    wb_country_code country_iso_code                    country_name  year  \
# 0              ARB               1A                      Arab World  1960
# 1              ARB               1A                      Arab World  1960
# 2              ARB               1A                      Arab World  1960
# 3              ARB               1A                      Arab World  1960
# 4              ARB               1A                      Arab World  1960
# 5              CSS               S3          Caribbean small states  1960
# 6              CSS               S3          Caribbean small states  1960
# 7              CSS               S3          Caribbean small states  1960
# 8              CSS               S3          Caribbean small states  1960
# 9              CSS               S3          Caribbean small states  1960
# 10             CEB               B8  Central Europe and the Baltics  1960
# 11             CEB               B8  Central Europe and the Baltics  1960
# 12             CEB               B8  Central Europe and the Baltics  1960
# 13             CEB               B8  Central Europe and the Baltics  1960
# 14             CEB               B8  Central Europe and the Baltics  1960
# 15             EAR               V2      Early-demographic dividend  1960
# 16             EAR               V2      Early-demographic dividend  1960
# 17             EAR               V2      Early-demographic dividend  1960
# 18             EAR               V2      Early-demographic dividend  1960
# 19             EAR               V2      Early-demographic dividend  1960
#
#     indicator_code  indicator_value
# 0      IT.CEL.SETS              0.0
# 1   SP.POP.0014.TO       40064255.0
# 2   SP.POP.1564.TO       49179481.0
# 3   SP.POP.65UP.TO        3247196.0
# 4      SP.POP.TOTL       92490932.0
# 5      IT.CEL.SETS              0.0
# 6   SP.POP.0014.TO        1766884.0
# 7   SP.POP.1564.TO        2151060.0
# 8   SP.POP.65UP.TO         169157.0
# 9      SP.POP.TOTL        4198307.0
# 10     IT.CEL.SETS              0.0
# 11  SP.POP.0014.TO       26671149.0
# 12  SP.POP.1564.TO       58135954.0
# 13  SP.POP.65UP.TO        6594481.0
# 14     SP.POP.TOTL       91401583.0
# 15     IT.CEL.SETS              0.0
# 16  SP.POP.0014.TO      403027249.0
# 17  SP.POP.1564.TO      543753940.0
# 18  SP.POP.65UP.TO       32506217.0
# 19     SP.POP.TOTL      979287407.0

# %%
countryPivot = countryIndicators.groupBy('country_iso_code', 'country_name', 'year') \
    .pivot('indicator_code').sum('indicator_value')

# %%
showDF(countryPivot.orderBy('country_iso_code', 'country_name', 'year'), limitRows=100)
# Out:
#    country_iso_code     country_name  year  IT.CEL.SETS IT.NET.BBND  \
# 0              None  Channel Islands  1960          NaN        None
# 1              None  Channel Islands  1961          NaN        None
# 2              None  Channel Islands  1962          NaN        None
# 3              None  Channel Islands  1963          NaN        None
# 4              None  Channel Islands  1964          NaN        None
# 5              None  Channel Islands  1965          NaN        None
# 6              None  Channel Islands  1966          NaN        None
# 7              None  Channel Islands  1967          NaN        None
# 8              None  Channel Islands  1968          NaN        None
# 9              None  Channel Islands  1969          NaN        None
# 10             None  Channel Islands  1970          NaN        None
# 11             None  Channel Islands  1971          NaN        None
# 12             None  Channel Islands  1972          NaN        None
# 13             None  Channel Islands  1973          NaN        None
# 14             None  Channel Islands  1974          NaN        None
# 15             None  Channel Islands  1975          NaN        None
# 16             None  Channel Islands  1976          NaN        None
# 17             None  Channel Islands  1977          NaN        None
# 18             None  Channel Islands  1978          NaN        None
# 19             None  Channel Islands  1979          NaN        None
# 20             None  Channel Islands  1980          NaN        None
# 21             None  Channel Islands  1981          NaN        None
# 22             None  Channel Islands  1982          NaN        None
# 23             None  Channel Islands  1983          NaN        None
# 24             None  Channel Islands  1984          NaN        None
# 25             None  Channel Islands  1985          NaN        None
# 26             None  Channel Islands  1986          NaN        None
# 27             None  Channel Islands  1987          NaN        None
# 28             None  Channel Islands  1988          NaN        None
# 29             None  Channel Islands  1989          NaN        None
# 30             None  Channel Islands  1990          NaN        None
# 31             None  Channel Islands  1991          NaN        None
# 32             None  Channel Islands  1992          NaN        None
# 33             None  Channel Islands  1993          NaN        None
# 34             None  Channel Islands  1994          NaN        None
# 35             None  Channel Islands  1995          NaN        None
# 36             None  Channel Islands  1996          NaN        None
# 37             None  Channel Islands  1997          NaN        None
# 38             None  Channel Islands  1998          NaN        None
# 39             None  Channel Islands  1999          NaN        None
# 40             None  Channel Islands  2000          NaN        None
# 41             None  Channel Islands  2001          NaN        None
# 42             None  Channel Islands  2002          NaN        None
# 43             None  Channel Islands  2003          NaN        None
# 44             None  Channel Islands  2004          NaN        None
# 45             None  Channel Islands  2005          NaN        None
# 46             None  Channel Islands  2006          NaN        None
# 47             None  Channel Islands  2007          NaN        None
# 48             None  Channel Islands  2008          NaN        None
# 49             None  Channel Islands  2009          NaN        None
# 50             None  Channel Islands  2010          NaN        None
# 51             None  Channel Islands  2011          NaN        None
# 52             None  Channel Islands  2012          NaN        None
# 53             None  Channel Islands  2013          NaN        None
# 54             None  Channel Islands  2014          NaN        None
# 55             None  Channel Islands  2015          NaN        None
# 56             None  Channel Islands  2016          NaN        None
# 57               1A       Arab World  1960          0.0        None
# 58               1A       Arab World  1961          NaN        None
# 59               1A       Arab World  1962          NaN        None
# 60               1A       Arab World  1963          NaN        None
# 61               1A       Arab World  1964          NaN        None
# 62               1A       Arab World  1965          0.0        None
# 63               1A       Arab World  1966          NaN        None
# 64               1A       Arab World  1967          NaN        None
# 65               1A       Arab World  1968          NaN        None
# 66               1A       Arab World  1969          NaN        None
# 67               1A       Arab World  1970          0.0        None
# 68               1A       Arab World  1971          NaN        None
# 69               1A       Arab World  1972          NaN        None
# 70               1A       Arab World  1973          NaN        None
# 71               1A       Arab World  1974          NaN        None
# 72               1A       Arab World  1975          0.0        None
# 73               1A       Arab World  1976          0.0        None
# 74               1A       Arab World  1977          0.0        None
# 75               1A       Arab World  1978          0.0        None
# 76               1A       Arab World  1979          0.0        None
# 77               1A       Arab World  1980          0.0        None
# 78               1A       Arab World  1981          0.0        None
# 79               1A       Arab World  1982       2330.0        None
# 80               1A       Arab World  1983       3564.0        None
# 81               1A       Arab World  1984       4936.0        None
# 82               1A       Arab World  1985       7976.0        None
# 83               1A       Arab World  1986      20756.0        None
# 84               1A       Arab World  1987      33793.0        None
# 85               1A       Arab World  1988      39447.0        None
# 86               1A       Arab World  1989      58750.0        None
# 87               1A       Arab World  1990      88618.0        None
# 88               1A       Arab World  1991     129904.0        None
# 89               1A       Arab World  1992     152281.0        None
# 90               1A       Arab World  1993     199350.0        None
# 91               1A       Arab World  1994     263401.0        None
# 92               1A       Arab World  1995     501551.0        None
# 93               1A       Arab World  1996     921229.0        None
# 94               1A       Arab World  1997    1616551.0        None
# 95               1A       Arab World  1998    2523542.0        None
# 96               1A       Arab World  1999    4105508.0        None
# 97               1A       Arab World  2000    9035241.0        None
# 98               1A       Arab World  2001   16679594.0        None
# 99               1A       Arab World  2002   25275663.0        None
#
#     SP.POP.0014.TO  SP.POP.1564.TO  SP.POP.65UP.TO  SP.POP.TOTL
# 0          23546.0         71467.0         14407.0     109420.0
# 1          23857.0         71951.0         14591.0     110399.0
# 2          23955.0         72685.0         14817.0     111457.0
# 3          24103.0         73419.0         15073.0     112595.0
# 4          24399.0         74038.0         15336.0     113773.0
# 5          24800.0         74587.0         15608.0     114995.0
# 6          25025.0         75355.0         15847.0     116227.0
# 7          25131.0         76242.0         16101.0     117474.0
# 8          25373.0         77002.0         16351.0     118726.0
# 9          25790.0         77576.0         16606.0     119972.0
# 10         26254.0         78072.0         16871.0     121197.0
# 11         26391.0         78830.0         17192.0     122413.0
# 12         26375.0         79758.0         17481.0     123614.0
# 13         26222.0         80763.0         17740.0     124725.0
# 14         25936.0         81772.0         17974.0     125682.0
# 15         25524.0         82714.0         18177.0     126415.0
# 16         25198.0         83174.0         18530.0     126902.0
# 17         24779.0         83596.0         18808.0     127183.0
# 18         24320.0         84063.0         19007.0     127390.0
# 19         23863.0         84692.0         19137.0     127692.0
# 20         23440.0         85534.0         19238.0     128212.0
# 21         23049.0         86537.0         19395.0     128981.0
# 22         22673.0         87785.0         19521.0     129979.0
# 23         22368.0         89154.0         19634.0     131156.0
# 24         22171.0         90541.0         19741.0     132453.0
# 25         22073.0         91877.0         19858.0     133808.0
# 26         22109.0         93083.0         20038.0     135230.0
# 27         22184.0         94318.0         20214.0     136716.0
# 28         22337.0         95483.0         20367.0     138187.0
# 29         22522.0         96529.0         20479.0     139530.0
# 30         22683.0         97455.0         20533.0     140671.0
# 31         23071.0         97806.0         20691.0     141568.0
# 32         23359.0         98098.0         20801.0     142258.0
# 33         23634.0         98319.0         20866.0     142819.0
# 34         23954.0         98530.0         20900.0     143384.0
# 35         24324.0         98799.0         20923.0     144046.0
# 36         24560.0         99235.0         21034.0     144829.0
# 37         24861.0         99749.0         21105.0     145715.0
# 38         25171.0        100351.0         21149.0     146671.0
# 39         25416.0        101055.0         21216.0     147687.0
# 40         25547.0        101874.0         21304.0     148725.0
# 41         25481.0        102630.0         21682.0     149793.0
# 42         25370.0        103486.0         22045.0     150901.0
# 43         25261.0        104417.0         22360.0     152038.0
# 44         25171.0        105360.0         22639.0     153170.0
# 45         25073.0        106253.0         22968.0     154294.0
# 46         25094.0        106861.0         23456.0     155411.0
# 47         24977.0        107566.0         23970.0     156513.0
# 48         24784.0        108347.0         24450.0     157581.0
# 49         24573.0        109159.0         24871.0     158603.0
# 50         24381.0        109915.0         25285.0     159581.0
# 51         24331.0        110357.0         25809.0     160497.0
# 52         24261.0        110718.0         26379.0     161358.0
# 53         24193.0        110995.0         26992.0     162180.0
# 54         24131.0        111202.0         27636.0     162969.0
# 55         24077.0        111362.0         28319.0     163758.0
# 56         24052.0        111452.0         29037.0     164541.0
# 57      40064255.0      49179481.0       3247196.0   92490932.0
# 58      41518715.0      50158016.0       3367766.0   95044497.0
# 59      42987169.0      51208328.0       3486797.0   97682294.0
# 60      44458639.0      52348368.0       3604069.0  100411076.0
# 61      45910606.0      53610121.0       3719175.0  103239902.0
# 62      47331020.0      55012095.0       3831873.0  106174988.0
# 63      48923976.0      56343748.0       3962869.0  109230593.0
# 64      50456294.0      57859656.0       4090982.0  112406932.0
# 65      51945966.0      59517129.0       4217070.0  115680165.0
# 66      53411639.0      61262878.0       4342025.0  119016542.0
# 67      54857512.0      63074009.0       4466853.0  122398374.0
# 68      56453735.0      64743285.0       4610399.0  125807419.0
# 69      57991493.0      66525027.0       4752855.0  129269375.0
# 70      59525243.0      68443969.0       4894204.0  132863416.0
# 71      61129366.0      70533559.0       5033836.0  136696761.0
# 72      62859354.0      72811620.0       5172324.0  140843298.0
# 73      64785694.0      75216468.0       5330216.0  145332378.0
# 74      66828081.0      77818854.0       5486119.0  150133054.0
# 75      68955334.0      80586837.0       5641553.0  155183724.0
# 76      71106520.0      83487468.0       5798500.0  160392488.0
# 77      73234442.0      86496611.0       5958437.0  165689490.0
# 78      75469309.0      89444551.0       6138090.0  171051950.0
# 79      77659213.0      92513772.0       6317099.0  176490084.0
# 80      79818025.0      95690461.0       6497341.0  182005827.0
# 81      81972127.0      98957605.0       6681024.0  187610756.0
# 82      84131860.0     102307492.0       6870949.0  193310301.0
# 83      86494332.0     105510462.0       7088973.0  199093767.0
# 84      88809494.0     108820444.0       7312611.0  204942549.0
# 85      91075462.0     112223266.0       7546043.0  210844771.0
# 86      93259426.0     115733643.0       7794333.0  216787402.0
# 87      96277669.0     120354864.0       8102913.0  224735446.0
# 88      98289704.0     124123536.0       8416628.0  230829868.0
# 89      99510372.0     126812158.0       8714650.0  235037179.0
# 90     101223904.0     131010463.0       9051724.0  241286091.0
# 91     102711484.0     135330556.0       9393890.0  247435930.0
# 92     104452866.0     140816007.0       9760798.0  255029671.0
# 93     105564857.0     145169463.0      10109142.0  260843462.0
# 94     106523081.0     149603044.0      10448950.0  266575075.0
# 95     107354429.0     154098379.0      10782338.0  272235146.0
# 96     108131446.0     158718005.0      11113418.0  277962869.0
# 97     108884238.0     163502786.0      11444991.0  283832016.0
# 98     109554629.0     168521819.0      11773908.0  289850357.0
# 99     110230211.0     173698045.0      12098319.0  296026575.0

# %%
#Write the regional-yearly totals to a CSV File
countryPivot.filter('country_iso_code is not null') \
    .orderBy('country_iso_code','country_name', 'year') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population') \
    .select(col('country_iso_code')
            , col('country_name')
            , col('year')
            , col('population').cast(DecimalType(38, 2))
            , col('population_age_0_to_14').cast(DecimalType(38, 2))
            , col('population_age_15_64').cast(DecimalType(38, 2))
            , col('population_age_65_and_above').cast(DecimalType(38, 2))
            , col('broadband_subscriptions').cast(DecimalType(38, 2))
            , col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('../output/CountryStats', mode='overwrite', header='true')

# %% [markdown]
# ## Excercise
#
# Kat wants to identify the countries that are conducive to start a business.  She thinks that it would suffice to look at the most recent metrics for the following:
# - Gross National Income (GNI)
# - Cost of business start-up procedures
# - Number of days required to start a business
# - Number of start-up procedures to register a business
# - GDP
# - GDP per capita
# - Business Regulatory Environment
# - Ease of doing business index (Only available in 2017)
#
# Write the data to a csv file.
#
# Hint - Start by matching up indicators that might have descriptions matching what Kat is looking for. e.g. <br>
# `showDF(seriesDim.filter("indicator_name like '%GNI%'").orderBy("indicator_code"), limitRows = 500)`

# %%
recentIndicators = indicatorsData \
    .select("wb_country_code", "indicator_code", "2016") \
    .filter(col('indicator_code').isin('IC.REG.COST.PC.ZS', 'IC.REG.DURS', 'IC.REG.PROC', \
        'NY.GNP.ATLS.CD', 'NY.GDP.MKTP.KD', 'NY.GDP.PCAP.KD', 'IQ.CPA.BREG.XQ', 'IC.BUS.EASE.XQ')) \
    .withColumnRenamed("2016", "indicator_value") \
    .withColumn("indicator_value", col("indicator_value").cast(DecimalType(38, 2)))

showDF(recentIndicators)
# Out:
#    wb_country_code     indicator_code   indicator_value
# 0              ARB  IC.REG.COST.PC.ZS             36.47
# 1              ARB     IQ.CPA.BREG.XQ              2.80
# 2              ARB     IC.BUS.EASE.XQ              None
# 3              ARB     NY.GDP.MKTP.KD  2616760000000.00
# 4              ARB     NY.GDP.PCAP.KD           6438.05
# 5              ARB     NY.GNP.ATLS.CD  2676040000000.00
# 6              ARB        IC.REG.PROC              8.32
# 7              ARB        IC.REG.DURS             23.17
# 8              CSS  IC.REG.COST.PC.ZS             19.90
# 9              CSS     IQ.CPA.BREG.XQ              3.90
# 10             CSS     IC.BUS.EASE.XQ              None
# 11             CSS     NY.GDP.MKTP.KD    63309462669.00
# 12             CSS     NY.GDP.PCAP.KD           8737.80
# 13             CSS     NY.GNP.ATLS.CD    64962563817.00
# 14             CSS        IC.REG.PROC              7.15
# 15             CSS        IC.REG.DURS             22.38
# 16             CEB  IC.REG.COST.PC.ZS              3.66
# 17             CEB     IQ.CPA.BREG.XQ              None
# 18             CEB     IC.BUS.EASE.XQ              None
# 19             CEB     NY.GDP.MKTP.KD  1519590000000.00

# %%
businessIndexIndicators = indicatorsData \
    .select("wb_country_code", "indicator_code", "2017") \
    .filter(col('indicator_code').isin('IC.BUS.EASE.XQ')) \
    .withColumnRenamed("2017", "indicator_value") \
    .withColumn("indicator_value", col("indicator_value").cast(DecimalType(38, 2)))

# %%
allIndicators = recentIndicators.union(businessIndexIndicators)

# %%
countryBusinessStartupPivot = allIndicators.join(countryDimFinal
                                       , recentIndicators.wb_country_code == countryDim.wb_country_code
                                       , "inner") \
    .select(countryDimFinal.country_iso_code
            , countryDimFinal.country_name
            , recentIndicators.indicator_code
            , recentIndicators.indicator_value) \
    .groupBy('country_iso_code', 'country_name').pivot('indicator_code').sum('indicator_value') \
    .withColumnRenamed('country_iso_code', 'Country ISO Code') \
    .withColumnRenamed('country_name', 'Country Name') \
    .withColumnRenamed('NY.GNP.ATLS.CD', 'GNI') \
    .withColumnRenamed('IC.REG.DURS', 'Startup Time') \
    .withColumnRenamed('IC.REG.PROC', 'Startup Procedures') \
    .withColumnRenamed('IC.REG.COST.PC.ZS', 'Startup Cost Pct of GNI') \
    .withColumnRenamed('NY.GDP.MKTP.KD', 'GDP') \
    .withColumnRenamed('NY.GDP.PCAP.KD', 'GDP Per Capita') \
    .withColumnRenamed('IQ.CPA.BREG.XQ', 'Business Regulation') \
    .withColumnRenamed('IC.BUS.EASE.XQ', 'Ease of business') \
    .withColumn('Startup Cost', (col('GNI') * col('Startup Cost Pct of GNI') / lit(100.0)).cast(DecimalType(38, 2))) \
    .filter(col('GNI') > 0) \
    .filter(col('Startup Time').isNotNull()) \
    .filter(col('Startup Procedures').isNotNull()) \
    .filter(col('Startup Cost').isNotNull())

# %%
showDF(countryBusinessStartupPivot, limitRows = 500)
# Out:
#     Country ISO Code                                       Country Name  \
# 0                 BJ                                              Benin
# 1                 XC                                          Euro area
# 2                 KZ                                         Kazakhstan
# 3                 JM                                            Jamaica
# 4                 NO                                             Norway
# 5                 IR                                               Iran
# 6                 AG                                Antigua and Barbuda
# 7                 CG                                              Congo
# 8                 AR                                          Argentina
# 9                 HT                                              Haiti
# 10                EU                                     European Union
# 11                XE             Heavily indebted poor countries (HIPC)
# 12                BB                                           Barbados
# 13                LT                                          Lithuania
# 14                SL                                       Sierra Leone
# 15                PK                                           Pakistan
# 16                SK                                    Slovak Republic
# 17                CN                                              China
# 18                T2             Latin America & Caribbean (IDA & IBRD)
# 19                SN                                            Senegal
# 20                MY                                           Malaysia
# 21                BO                                            Bolivia
# 22                SA                                       Saudi Arabia
# 23                IL                                             Israel
# 24                V4                          Post-demographic dividend
# 25                MT                                              Malta
# 26                XN                                Lower middle income
# 27                CL                                              Chile
# 28                ZF         Sub-Saharan Africa (excluding high income)
# 29                JP                                              Japan
# 30                DZ                                            Algeria
# 31                T5                            South Asia (IDA & IBRD)
# 32                KN                                St. Kitts and Nevis
# 33                VC                     St. Vincent and the Grenadines
# 34                TD                                               Chad
# 35                ZT                                   IDA & IBRD total
# 36                LR                                            Liberia
# 37                7E      Europe & Central Asia (excluding high income)
# 38                ML                                               Mali
# 39                SV                                        El Salvador
# 40                KG                                    Kyrgyz Republic
# 41                HU                                            Hungary
# 42                TJ                                         Tajikistan
# 43                XO                                Low & middle income
# 44                NE                                              Niger
# 45                MD                                            Moldova
# 46                TR                                             Turkey
# 47                XD                                        High income
# 48                LU                                         Luxembourg
# 49                AM                                            Armenia
# 50                V2                         Early-demographic dividend
# 51                TO                                              Tonga
# 52                TH                                           Thailand
# 53                XG                                          IDA total
# 54                OE                                       OECD members
# 55                VN                                            Vietnam
# 56                ID                                          Indonesia
# 57                SE                                             Sweden
# 58                MZ                                         Mozambique
# 59                CR                                         Costa Rica
# 60                HK                               Hong Kong SAR, China
# 61                NZ                                        New Zealand
# 62                GM                                         The Gambia
# 63                MH                                   Marshall Islands
# 64                IE                                            Ireland
# 65                PA                                             Panama
# 66                CY                                             Cyprus
# 67                NA                                            Namibia
# 68                KI                                           Kiribati
# 69                CD                                    Dem. Rep. Congo
# 70                SG                                          Singapore
# 71                SR                                           Suriname
# 72                GE                                            Georgia
# 73                UY                                            Uruguay
# 74                UZ                                         Uzbekistan
# 75                ZG                                 Sub-Saharan Africa
# 76                PL                                             Poland
# 77                XF                                          IBRD only
# 78                HR                                            Croatia
# 79                JO                                             Jordan
# 80                EC                                            Ecuador
# 81                DE                                            Germany
# 82                WS                                              Samoa
# 83                Z7                              Europe & Central Asia
# 84                HN                                           Honduras
# 85                MR                                         Mauritania
# 86                BS                                        The Bahamas
# 87                T6                    Sub-Saharan Africa (IDA & IBRD)
# 88                MG                                         Madagascar
# 89                KW                                             Kuwait
# 90                FR                                             France
# 91                LB                                            Lebanon
# 92                XL       Least developed countries: UN classification
# 93                RW                                             Rwanda
# 94                TT                                Trinidad and Tobago
# 95                TZ                                           Tanzania
# 96                NP                                              Nepal
# 97                F1           Fragile and conflict affected situations
# 98                SZ                                          Swaziland
# 99                ZQ                         Middle East & North Africa
# 100               GN                                             Guinea
# 101               NL                                        Netherlands
# 102               XK                                             Kosovo
# 103               AO                                             Angola
# 104               ZJ                          Latin America & Caribbean
# 105               BW                                           Botswana
# 106               Z4                                East Asia & Pacific
# 107               T4                   East Asia & Pacific (IDA & IBRD)
# 108               IQ                                               Iraq
# 109               XP                                      Middle income
# 110               PH                                        Philippines
# 111               S3                             Caribbean small states
# 112               GB                                     United Kingdom
# 113               PS                                 West Bank and Gaza
# 114               XT                                Upper middle income
# 115               EE                                            Estonia
# 116               CZ                                     Czech Republic
# 117               AU                                          Australia
# 118               SB                                    Solomon Islands
# 119               MM                                            Myanmar
# 120               AF                                        Afghanistan
# 121               DK                                            Denmark
# 122               AE                               United Arab Emirates
# 123               BD                                         Bangladesh
# 124               ET                                           Ethiopia
# 125               V3                          Late-demographic dividend
# 126               GR                                             Greece
# 127               US                                      United States
# 128               FI                                            Finland
# 129               DM                                           Dominica
# 130               ME                                         Montenegro
# 131               T7                 Europe & Central Asia (IDA & IBRD)
# 132               XI                                           IDA only
# 133               KR                                              Korea
# 134               S2                        Pacific island small states
# 135               ZW                                           Zimbabwe
# 136               ZM                                             Zambia
# 137               CA                                             Canada
# 138               BN                                             Brunei
# 139               GA                                              Gabon
# 140               BR                                             Brazil
# 141               XM                                         Low income
# 142               XJ  Latin America & Caribbean (excluding high income)
# 143               BF                                       Burkina Faso
# 144               MW                                             Malawi
# 145               XQ  Middle East & North Africa (excluding high inc...
# 146               4E        East Asia & Pacific (excluding high income)
# 147               BZ                                             Belize
# 148               NI                                          Nicaragua
# 149               BG                                           Bulgaria
# 150               1A                                         Arab World
# 151               PT                                           Portugal
# 152               MV                                           Maldives
# 153               BY                                            Belarus
# 154               IN                                              India
# 155               ST                              São Tomé and Principe
# 156               YE                                              Yemen
# 157               LV                                             Latvia
# 158               FM                                         Micronesia
# 159               SD                                              Sudan
# 160               LA                                            Lao PDR
# 161               RU                                             Russia
# 162               CM                                           Cameroon
# 163               UG                                             Uganda
# 164               CF                           Central African Republic
# 165               BT                                             Bhutan
# 166               V1                           Pre-demographic dividend
# 167               CV                                         Cabo Verde
# 168               XH                                          IDA blend
# 169               IS                                            Iceland
# 170               KM                                            Comoros
# 171               CO                                           Colombia
# 172               LS                                            Lesotho
# 173               PW                                              Palau
# 174               TL                                        Timor-Leste
# 175               PE                                               Peru
# 176               GT                                          Guatemala
# 177               MU                                          Mauritius
# 178               ZA                                       South Africa
# 179               ES                                              Spain
# 180               BI                                            Burundi
# 181               TG                                               Togo
# 182               LK                                          Sri Lanka
# 183               GY                                             Guyana
# 184               RO                                            Romania
# 185               MN                                           Mongolia
# 186               LC                                          St. Lucia
# 187               NG                                            Nigeria
# 188               RS                                             Serbia
# 189               BE                                            Belgium
# 190               GH                                              Ghana
# 191               KE                                              Kenya
# 192               GQ                                  Equatorial Guinea
# 193               PR                                        Puerto Rico
# 194               AZ                                         Azerbaijan
# 195               PG                                   Papua New Guinea
# 196               8S                                         South Asia
# 197               MA                                            Morocco
# 198               T3            Middle East & North Africa (IDA & IBRD)
# 199               UA                                            Ukraine
# 200               SC                                         Seychelles
# 201               EG                                              Egypt
# 202               GD                                            Grenada
# 203               PY                                           Paraguay
# 204               BA                             Bosnia and Herzegovina
# 205               FJ                                               Fiji
# 206               GW                                      Guinea-Bissau
# 207               MK                                          Macedonia
# 208               MX                                             Mexico
# 209               DO                                 Dominican Republic
# 210               TN                                            Tunisia
# 211               KH                                           Cambodia
# 212               IT                                              Italy
# 213               CH                                        Switzerland
# 214               B8                     Central Europe and the Baltics
# 215               1W                                              World
# 216               CI                                      Côte d'Ivoire
# 217               AT                                            Austria
# 218               SI                                           Slovenia
# 219               XU                                      North America
# 220               AL                                            Albania
#
#     Ease of business Startup Cost Pct of GNI Startup Time Startup Procedures  \
# 0             151.00                    3.80         8.50               6.00
# 1               None                    3.83         9.55               5.26
# 2              36.00                    0.30         9.00               5.00
# 3              70.00                    4.30        10.00               2.00
# 4               8.00                    0.90         4.00               4.00
# 5             124.00                    1.20        15.50               9.00
# 6             107.00                    9.40        22.00               9.00
# 7             179.00                   61.20        50.00              11.00
# 8             117.00                   10.80        24.00              13.00
# 9             181.00                  219.30        97.00              12.00
# 10              None                    3.89        10.41               5.43
# 11              None                   57.09        22.54               7.74
# 12            132.00                    7.70        15.00               8.00
# 13             16.00                    0.60         5.50               4.00
# 14            160.00                   30.30        10.00               6.00
# 15            147.00                   12.50        18.00              12.00
# 16             39.00                    1.20        12.50               7.00
# 17             78.00                    0.70        26.90               7.00
# 18              None                   33.17        32.95               8.53
# 19            140.00                   62.70         6.00               4.00
# 20             24.00                    6.20        18.50               8.00
# 21            152.00                   53.50        45.00              14.00
# 22             92.00                    6.00        19.30              14.00
# 23             54.00                    3.30        12.00               4.00
# 24              None                    3.87        10.22               5.47
# 25             84.00                   12.30        26.00               9.00
# 26              None                   26.21        21.16               7.74
# 27             55.00                    3.20         5.50               7.00
# 28              None                   55.50        27.76               8.04
# 29             34.00                    7.50        12.20               9.00
# 30            166.00                   11.10        20.00              12.00
# 31              None                   13.64        15.81               8.13
# 32            134.00                    7.20        18.50               7.00
# 33            129.00                   16.10        10.00               7.00
# 34            180.00                  159.80        60.00               9.00
# 35              None                   33.38        25.06               7.68
# 36            172.00                   16.70         6.00               5.00
# 37              None                    4.77        11.10               5.29
# 38            143.00                   61.00         8.50               5.00
# 39             73.00                   41.40        16.50               9.00
# 40             77.00                    2.20        10.00               4.00
# 41             48.00                    7.10         7.00               6.00
# 42            123.00                   16.80        22.00               5.00
# 43              None                   34.94        25.50               7.73
# 44            144.00                   32.40        10.00               4.00
# 45             44.00                    6.20         6.00               5.00
# 46             60.00                   17.60         6.50               7.00
# 47              None                    4.65        11.29               5.70
# 48             63.00                    1.70        16.50               5.00
# 49             47.00                    0.90         4.50               4.00
# 50              None                   33.81        31.80               8.79
# 51             89.00                    6.80        16.00               4.00
# 52             26.00                    6.60        27.50               6.00
# 53              None                   48.35        22.05               7.22
# 54              None                    4.14         8.46               5.06
# 55             68.00                    4.60        24.00               9.00
# 56             72.00                   19.40        24.90              11.00
# 57             10.00                    0.50         7.00               3.00
# 58            138.00                   18.00        19.00              10.00
# 59             61.00                    9.10        22.50               9.00
# 60              5.00                    0.60         1.50               2.00
# 61              1.00                    0.30         0.50               1.00
# 62            146.00                  125.20        25.00               7.00
# 63            149.00                   12.50        17.00               5.00
# 64             17.00                    0.20         5.00               3.00
# 65             79.00                    5.80         6.00               5.00
# 66             53.00                   12.20         6.00               5.00
# 67            106.00                   11.50        66.00              10.00
# 68            157.00                   36.30        31.00               7.00
# 69            182.00                   29.30        11.50               7.00
# 70              2.00                    0.60         2.50               3.00
# 71            165.00                  101.40        84.50              13.00
# 72              9.00                    2.60         2.00               2.00
# 73             94.00                   22.50         6.50               5.00
# 74             74.00                    3.20         5.50               4.00
# 75              None                   54.63        27.85               8.06
# 76             27.00                   12.10        37.00               5.00
# 77              None                   16.84        28.39               8.19
# 78             51.00                    7.30         7.00               8.00
# 79            103.00                   20.60        12.50               7.00
# 80            118.00                   21.00        48.50              11.00
# 81             20.00                    1.90        10.50               9.00
# 82             87.00                    7.70         9.00               4.00
# 83              None                    4.09        10.09               5.22
# 84            115.00                   41.10        13.00              11.00
# 85            150.00                   19.40         8.00               7.00
# 86            119.00                   13.80        21.50               8.00
# 87              None                   54.63        27.85               8.06
# 88            162.00                   40.40        11.00               7.00
# 89             96.00                    2.80        61.40              12.00
# 90             31.00                    0.70         3.50               5.00
# 91            133.00                   40.60        15.00               8.00
# 92              None                   61.78        24.64               7.63
# 93             41.00                   48.50         4.00               5.00
# 94            102.00                    0.60        10.50               7.00
# 95            137.00                   48.10        28.00              11.00
# 96            105.00                   26.10        17.00               7.00
# 97              None                   75.39        28.16               7.86
# 98            112.00                   16.60        30.00              12.00
# 99              None                   23.54        20.60               8.05
# 100           153.00                   77.70         8.00               6.00
# 101            32.00                    4.50         3.50               4.00
# 102            40.00                    1.10         6.00               3.00
# 103           175.00                   20.70        36.00               7.00
# 104             None                   30.84        31.22               8.42
# 105            81.00                    0.80        48.00               9.00
# 106             None                   17.16        21.43               6.62
# 107             None                   22.36        27.32               7.71
# 108           168.00                   51.90        34.50               9.00
# 109             None                   22.03        25.52               7.73
# 110           113.00                   15.80        28.00              16.00
# 111             None                   19.90        22.38               7.15
# 112             7.00                    0.10         4.50               4.00
# 113           114.00                   46.90        43.50              10.00
# 114             None                   17.68        30.05               7.73
# 115            12.00                    1.20         3.50               3.00
# 116            30.00                    5.70         9.00               8.00
# 117            14.00                    0.70         2.50               3.00
# 118           116.00                   28.50         9.00               7.00
# 119           171.00                   41.10        14.00              12.00
# 120           183.00                   19.90         7.50               3.00
# 121             3.00                    0.20         3.50               5.00
# 122            21.00                   13.00         8.20               4.00
# 123           177.00                   15.60        19.50               9.00
# 124           161.00                   69.30        35.00              14.00
# 125             None                    7.01        14.76               6.10
# 126            67.00                    2.20        13.00               5.00
# 127             6.00                    1.10         5.60               6.00
# 128            13.00                    1.00        14.00               3.00
# 129            98.00                   15.70        12.00               5.00
# 130            42.00                    1.50        10.00               6.00
# 131             None                    5.10        12.28               5.27
# 132             None                   54.84        22.03               7.28
# 133             4.00                   14.60         4.00               2.00
# 134             None                   33.03        20.44               6.67
# 135           159.00                  121.50        91.00              10.00
# 136            85.00                   34.70         8.50               7.00
# 137            18.00                    0.40         1.50               2.00
# 138            56.00                    1.50        14.50               7.00
# 139           167.00                   14.30        47.00               9.00
# 140           125.00                    5.20        79.50              11.00
# 141             None                   79.72        25.45               7.73
# 142             None                   38.08        37.02               8.84
# 143           148.00                   43.40        13.00               3.00
# 144           110.00                   42.20        37.00               7.00
# 145             None                   34.28        21.65               8.23
# 146             None                   23.34        27.29               7.70
# 147           121.00                   34.60        43.00               9.00
# 148           131.00                   68.00        14.00               7.00
# 149            50.00                    1.30        23.00               7.00
# 150             None                   36.47        23.17               8.32
# 151            29.00                    2.10         5.00               6.00
# 152           136.00                    5.20        12.00               6.00
# 153            38.00                    0.60         5.00               5.00
# 154           100.00                   13.80        28.50              13.00
# 155           169.00                   15.20         7.00               6.00
# 156           186.00                   82.20        40.50               6.00
# 157            19.00                    1.80         5.50               4.00
# 158           155.00                  140.40        16.00               7.00
# 159           170.00                   30.50        36.50              11.00
# 160           141.00                    4.60        67.00               8.00
# 161            35.00                    1.20        10.10               4.00
# 162           163.00                   32.20        16.50               7.00
# 163           122.00                   37.10        26.00              13.00
# 164           184.00                  186.00        22.00              10.00
# 165            75.00                    3.80        15.00               8.00
# 166             None                   63.21        24.93               7.68
# 167           127.00                   14.70        11.00               8.00
# 168             None                   24.83        22.12               7.00
# 169            23.00                    2.00        11.50               5.00
# 170           158.00                   98.40        16.00               9.00
# 171            59.00                   14.10        11.00               8.00
# 172           104.00                    8.10        29.00               7.00
# 173           130.00                    2.90        28.00               8.00
# 174           178.00                    0.50         9.00               4.00
# 175            58.00                    9.90        26.50               7.00
# 176            97.00                   24.10        26.50               8.00
# 177            25.00                    1.80         6.50               5.00
# 178            82.00                    0.20        45.00               7.00
# 179            28.00                    5.00        13.00               7.00
# 180           164.00                   13.90         4.00               3.00
# 181           156.00                   71.20         6.00               5.00
# 182           111.00                   12.20         9.00               7.00
# 183           126.00                   10.70        18.00               7.00
# 184            45.00                    2.00        12.00               6.00
# 185            62.00                    1.50        10.00               6.00
# 186            91.00                   21.40        11.00               5.00
# 187           145.00                   31.00        24.90               8.00
# 188            43.00                    6.50         6.50               5.00
# 189            52.00                    5.00         4.00               3.00
# 190           120.00                   19.70        14.00               8.00
# 191            80.00                   28.20        23.00               8.00
# 192           173.00                  102.70       149.00              17.00
# 193            64.00                    1.30         5.50               6.00
# 194            57.00                    1.90         4.50               4.00
# 195           109.00                   15.60        41.00               6.00
# 196             None                   13.64        15.81               8.13
# 197            69.00                    7.90        10.00               5.00
# 198             None                   33.23        19.83               8.08
# 199            76.00                    0.90         6.50               6.00
# 200            95.00                   13.40        32.00               9.00
# 201           128.00                    7.60        14.50               8.00
# 202           142.00                   15.80        15.00               6.00
# 203           108.00                   39.80        35.00               7.00
# 204            86.00                   13.50        65.00              12.00
# 205           101.00                   17.90        40.00              11.00
# 206           176.00                   52.90         8.50               9.00
# 207            11.00                    0.10         7.00               4.00
# 208            49.00                   17.80         8.40               8.00
# 209            99.00                   14.80        18.50               7.00
# 210            88.00                    4.70        11.00               9.00
# 211           135.00                   55.70        99.00               9.00
# 212            46.00                   13.90         6.50               6.00
# 213            33.00                    2.30        10.00               6.00
# 214             None                    3.66        11.73               5.64
# 215             None                   26.01        21.31               7.13
# 216           139.00                   18.90         7.00               4.00
# 217            22.00                    5.20        21.00               8.00
# 218            37.00                    0.00         7.00               4.00
# 219             None                    0.75         3.55               4.00
# 220            65.00                   12.50         5.00               5.00
#
#     Business Regulation                GDP GDP Per Capita                GNI  \
# 0                  3.00      9103831278.00         837.34      8938879520.00
# 1                  None  13377100000000.00       39256.27  12312600000000.00
# 2                  None    188309000000.00       10582.50    156812000000.00
# 3                  None     13801803130.00        4790.04     13349534142.00
# 4                  None    472766000000.00       90288.82    429276000000.00
# 5                  None    540581000000.00        6733.91    438869000000.00
# 6                  None      1344373698.00       13315.51      1369440563.00
# 7                  2.50     14342385958.00        2798.07      8770006555.00
# 8                  None    445227000000.00       10154.00    524974000000.00
# 9                  2.00      7910618370.00         729.27      8488280524.00
# 10                 None  18308600000000.00       35803.61  17044000000000.00
# 11                 3.04    635297000000.00         853.20    639767000000.00
# 12                 None      4629124472.00       16242.77      4336068302.00
# 13                 None     45735444769.00       15945.52     42430236294.00
# 14                 3.00      3369621899.00         455.59      3642914089.00
# 15                 3.50    227748000000.00        1178.80    289101000000.00
# 16                 None    104679000000.00       19275.09     92362394160.00
# 17                 None   9504210000000.00        6893.78  11374200000000.00
# 18                 3.50   5695180000000.00        9163.09   5111880000000.00
# 19                 3.50     16833353304.00        1092.25     14648720074.00
# 20                 None    344052000000.00       11031.82    307408000000.00
# 21                 None     26758341469.00        2457.63     33454117288.00
# 22                 None    690550000000.00       21395.36    701154000000.00
# 23                 None    287808000000.00       33677.46    309784000000.00
# 24                 None  46639100000000.00       42297.25  45659800000000.00
# 25                 None     11625545301.00       26577.66     10579899295.00
# 26                 3.12   6382940000000.00        2117.21   6262980000000.00
# 27                 None    268998000000.00       15019.63    242506000000.00
# 28                 3.07   1691600000000.00        1637.38   1564980000000.00
# 29                 None   6052670000000.00       47660.89   4825580000000.00
# 30                 None    196035000000.00        4827.72    171379000000.00
# 31                 3.25   2987260000000.00        1691.17   2845250000000.00
# 32                 None       858344692.40       15657.22       860090639.50
# 33                 4.00       732044136.00        6676.62       742788471.10
# 34                 2.50     12424107945.00         859.65     10366907935.00
# 35                 3.10  28219500000000.00        4498.16  28459900000000.00
# 36                 3.00      1627046588.00         352.65      1720256072.00
# 37                 3.50   3768050000000.00        9027.29   3211660000000.00
# 38                 3.50     13421822111.00         745.87     13833191217.00
# 39                 None     24128087317.00        3802.86     24849373694.00
# 40                 4.00      6315715818.00        1038.85      6714376146.00
# 41                 None    147183000000.00       14997.20    123366000000.00
# 42                 3.00      8458800788.00         968.39      9661732023.00
# 43                 3.10  27414100000000.00        4383.41  27771200000000.00
# 44                 3.50      8085878853.00         391.13      7679782128.00
# 45                 3.50      7326645709.00        2062.71      7513233350.00
# 46                 None   1122480000000.00       14116.98    892975000000.00
# 47                 None  50177300000000.00       42167.41  49090400000000.00
# 48                 None     63207264513.00      108600.93     41667358966.00
# 49                 None     11501998666.00        3932.55     11033089155.00
# 50                 3.10  11071400000000.00        3491.83  10426700000000.00
# 51                 3.00       406237705.30        3792.29       434923730.30
# 52                 None    406424000000.00        5901.88    388294000000.00
# 53                 3.10   1910240000000.00        1213.35   2053250000000.00
# 54                 None  49580500000000.00       38438.33  48108800000000.00
# 55                 None    164105000000.00        1735.29    194829000000.00
# 56                 None   1037690000000.00        3974.06    888958000000.00
# 57                 None    560387000000.00       56473.02    543465000000.00
# 58                 3.00     14858345267.00         515.39     13788015918.00
# 59                 None     47184044863.00        9714.10     52643876714.00
# 60                 None    269812000000.00       36776.21    315035000000.00
# 61                 None    171405000000.00       36521.96    181349000000.00
# 62                 3.50      1084315801.00         531.92       881023377.50
# 63                 2.50       179041793.90        3373.95       245502476.40
# 64                 None    332361000000.00       69974.10    256365000000.00
# 65                 None     44304199791.00       10982.37     48989232938.00
# 66                 None     24225907615.00       28448.82     20714181469.00
# 67                 None     14990403316.00        6045.22     11514552447.00
# 68                 2.50       192869084.40        1685.99       259841031.90
# 69                 3.00     30547324905.00         387.97     36266263854.00
# 70                 None    294947000000.00       52600.64    290912000000.00
# 71                 None      4527379879.00        8108.24      3902912447.00
# 72                 None     15189614348.00        4084.00     14259354498.00
# 73                 None     48250518688.00       14010.00     52448603839.00
# 74                 3.00     62469088152.00        1961.48     70840642417.00
# 75                 3.07   1692930000000.00        1638.51   1566440000000.00
# 76                 None    572056000000.00       15065.97    481401000000.00
# 77                 None  26313800000000.00        5599.59  26414900000000.00
# 78                 None     60328288796.00       14452.14     50624848734.00
# 79                 None     30811666897.00        3258.49     37056807858.00
# 80                 None     85056519293.00        5191.10     95089220805.00
# 81                 None   3781700000000.00       45845.53   3624640000000.00
# 82                 3.50       738041747.00        3782.40       803834103.80
# 83                 3.50  22920400000000.00       25136.24  21125500000000.00
# 84                 3.00     19481561981.00        2137.81     19551625964.00
# 85                 3.00      5574151403.00        1296.01      4845287025.00
# 86                 None      7821154995.00       19991.09     10362829370.00
# 87                 3.07   1692930000000.00        1638.51   1566440000000.00
# 88                 3.00     10356200860.00         416.00      9883770514.00
# 89                 None    142857000000.00       35250.91    141393000000.00
# 90                 None   2810530000000.00       42015.74   2590030000000.00
# 91                 None     42911390492.00        7143.96     47958899959.00
# 92                 2.96    870874000000.00         889.20    936371000000.00
# 93                 4.50      8802737510.00         738.64      8392529142.00
# 94                 None     22192974037.00       16259.04     22168666727.00
# 95                 3.50     46776367082.00         867.06     48508571081.00
# 96                 3.50     19856634053.00         685.12     21019533596.00
# 97                 2.67    769502000000.00        1521.85    776271000000.00
# 98                 None      5246492516.00        3906.26      3975336562.00
# 99                 2.50   3373550000000.00        7724.73   3342810000000.00
# 100                3.00      9119962270.00         735.72      8315219892.00
# 101                None    890136000000.00       52267.73    793747000000.00
# 102                4.00      7065141676.00        3890.07      6999904953.00
# 103                None    103228000000.00        3582.65     99404127946.00
# 104                3.50   5891560000000.00        9239.22   5274990000000.00
# 105                None     16839085218.00        7483.17     15184507230.00
# 106                2.82  21926800000000.00        9538.69  22647700000000.00
# 107                2.82  11883900000000.00        5860.21  13663200000000.00
# 108                None    211894000000.00        5695.68    201647000000.00
# 109                3.19  27019600000000.00        4829.41  27364100000000.00
# 110                None    284477000000.00        2753.35    369969000000.00
# 111                3.90     63309462669.00        8737.80     64962563817.00
# 112                None   2757620000000.00       42039.74   2778980000000.00
# 113                None     11700600216.00        2570.68     14714599201.00
# 114                3.45  20636100000000.00        7998.46  21095100000000.00
# 115                None     23808677023.00       18094.59     23466752946.00
# 116                None    231340000000.00       21894.11    186287000000.00
# 117                None   1343180000000.00       55478.58   1313020000000.00
# 118                3.00       886746423.40        1479.34      1128459642.00
# 119                2.50     74469832820.00        1408.14     63085857664.00
# 120                2.50     21413614655.00         617.89     19979001577.00
# 121                None    347520000000.00       60670.24    326440000000.00
# 122                None    378796000000.00       40864.25    375190000000.00
# 123                3.00    167771000000.00        1029.58    216291000000.00
# 124                3.00     52347226230.00         511.19     67515416835.00
# 125                3.75  18000300000000.00        7948.66  18868300000000.00
# 126                None    244481000000.00       22699.08    203369000000.00
# 127                None  16920300000000.00       52364.24  18369800000000.00
# 128                None    252692000000.00       45983.31    247520000000.00
# 129                4.00       506021854.10        6880.63       523202386.90
# 130                None      4662830252.00        7492.86      4431410088.00
# 131                3.50   4340110000000.00        9530.80   3693060000000.00
# 132                3.04    992211000000.00         942.10   1059490000000.00
# 133                None   1304660000000.00       25458.89   1414400000000.00
# 134                2.75      7645725974.00        3200.56      8834056731.00
# 135                2.00     14818986159.00         917.56     14381419482.00
# 136                3.50     26998749244.00        1627.27     22586395119.00
# 137                None   1828000000000.00       50407.34   1591320000000.00
# 138                None     13301457646.00       31430.96     13906153846.00
# 139                None     18945471826.00        9569.45     14269826260.00
# 140                None   2248110000000.00       10826.27   1835990000000.00
# 141                2.95    394634000000.00         598.59    407265000000.00
# 142                3.50   5425980000000.00        8893.06   4853920000000.00
# 143                3.50     12379492024.00         663.91     11496223896.00
# 144                3.00      8710223822.00         481.45      5789902905.00
# 145                2.50   1579580000000.00        4226.66   1510670000000.00
# 146                2.82  11906700000000.00        5798.84  13689200000000.00
# 147                None      1588184522.00        4328.02      1598991964.00
# 148                3.50     11970056313.00        1946.37     12933034661.00
# 149                None     56792409375.00        7967.71     54056749422.00
# 150                2.80   2616760000000.00        6438.05   2676040000000.00
# 151                None    231745000000.00       22444.07    205134000000.00
# 152                3.50      3600398623.00        8416.94      4438893209.00
# 153                None     59112583221.00        6221.37     53188398533.00
# 154                None   2464930000000.00        1861.49   2212310000000.00
# 155                3.00       256661791.70        1283.89       342845695.30
# 156                2.50     18748089228.00         679.67     28774101437.00
# 157                None     28872727303.00       14734.46     28557587168.00
# 158                2.00       296282644.00        2823.43       372172317.70
# 159                3.00     76149479922.00        1924.00     84892757237.00
# 160                3.50     11102149875.00        1642.73     14516384762.00
# 161                None   1654430000000.00       11279.63   1425700000000.00
# 162                3.00     35051979601.00        1495.44     32823298308.00
# 163                4.00     27483052192.00         662.43     26270858516.00
# 164                2.00      1496561293.00         325.72      1722908633.00
# 165                3.50      2234759342.00        2801.28      2000473716.00
# 166                2.95   1309250000000.00        1488.98   1291570000000.00
# 167                3.50      1863071658.00        3452.95      1604474138.00
# 168                3.31    912125000000.00        1750.18    986768000000.00
# 169                None     16434890268.00       48995.17     19039081038.00
# 170                3.00       611370805.20         768.44       612409068.10
# 171                None    366159000000.00        7525.86    307204000000.00
# 172                3.50      2980616573.00        1352.48      2797076776.00
# 173                None       234595684.90       10909.90       265059108.40
# 174                2.00      1192299136.00         939.80      2610846967.00
# 175                None    193484000000.00        6089.40    189039000000.00
# 176                None     51409073372.00        3100.21     62845811883.00
# 177                None     12409842083.00        9822.01     12338608253.00
# 178                None    419499000000.00        7488.99    306939000000.00
# 179                None   1464510000000.00       31505.29   1281830000000.00
# 180                3.00      2297241392.00         218.28      2924463063.00
# 181                3.00      4245259745.00         558.12      4089869107.00
# 182                None     79706946035.00        3759.23     80109977364.00
# 183                3.00      2925825406.00        3783.54      3275291569.00
# 184                None    198283000000.00       10065.49    186762000000.00
# 185                3.50     11825367387.00        3906.12     10873592260.00
# 186                4.50      1451113155.00        8151.63      1495763568.00
# 187                3.50    456775000000.00        2455.92    455988000000.00
# 188                None     41308012850.00        5852.38     37484221645.00
# 189                None    515557000000.00       45469.71    483168000000.00
# 190                4.00     48167546935.00        1707.66     38863877194.00
# 191                3.50     55394739178.00        1143.07     66885890618.00
# 192                None     14997611965.00       12278.13      8766316571.00
# 193                None     93028633826.00       27270.67     66295282781.00
# 194                None     57195531762.00        5861.51     46454548215.00
# 195                3.00     19696493854.00        2436.18     21636888223.00
# 196                3.25   2987260000000.00        1691.17   2845250000000.00
# 197                None    114784000000.00        3204.86    103208000000.00
# 198                2.50   1567800000000.00        4246.85   1495660000000.00
# 199                None    124000000000.00        2905.86     98628598631.00
# 200                None      1322030966.00       13963.59      1459397660.00
# 201                None    260694000000.00        2724.40    326256000000.00
# 202                4.00       931118693.50        8676.34       976983667.00
# 203                None     26400622643.00        3925.56     27337551522.00
# 204                None     18912863953.00        5377.84     17367331463.00
# 205                None      3771168302.00        4195.97      4296564665.00
# 206                2.50      1057415318.00         582.37      1084805836.00
# 207                None     10869778362.00        5222.83     10374069290.00
# 208                None   1238150000000.00        9707.91   1153530000000.00
# 209                None     73573876510.00        6909.13     68030364512.00
# 210                None     48639094593.00        4265.37     42118869654.00
# 211                3.00     17009386902.00        1079.11     17941748456.00
# 212                None   2080640000000.00       34318.50   1921650000000.00
# 213                None    642090000000.00       76691.12    687324000000.00
# 214                None   1519590000000.00       14754.55   1314120000000.00
# 215                3.10  77564700000000.00       10419.72  76830500000000.00
# 216                3.00     36794322093.00        1552.77     36025837768.00
# 217                None    420040000000.00       48106.49    400590000000.00
# 218                None     50511749002.00       24460.40     44807704834.00
# 219                None  18753800000000.00       52172.61  19968500000000.00
# 220                None     13474438372.00        4684.97     12009983567.00
#
#           Startup Cost
# 0         339677421.76
# 1      471572580000.00
# 2         470436000.00
# 3         574029968.11
# 4        3863484000.00
# 5        5266428000.00
# 6         128727412.92
# 7        5367244011.66
# 8       56697192000.00
# 9       18614799189.13
# 10     663011600000.00
# 11     365242980300.00
# 12        333877259.25
# 13        254581417.76
# 14       1103802968.97
# 15      36137625000.00
# 16       1108348729.92
# 17      79619400000.00
# 18    1695610596000.00
# 19       9184747486.40
# 20      19059296000.00
# 21      17897952749.08
# 22      42069240000.00
# 23      10222872000.00
# 24    1767034260000.00
# 25       1301327613.29
# 26    1641527058000.00
# 27       7760192000.00
# 28     868563900000.00
# 29     361918500000.00
# 30      19023069000.00
# 31     388092100000.00
# 32         61926526.04
# 33        119588943.85
# 34      16566318880.13
# 35    9499914620000.00
# 36        287282764.02
# 37     153196182000.00
# 38       8438246642.37
# 39      10287640709.32
# 40        147716275.21
# 41       8758986000.00
# 42       1623170979.86
# 43    9703257280000.00
# 44       2488249409.47
# 45        465820467.70
# 46     157163600000.00
# 47    2282703600000.00
# 48        708345102.42
# 49         99297802.40
# 50    3525267270000.00
# 51         29574813.66
# 52      25627404000.00
# 53     992746375000.00
# 54    1991704320000.00
# 55       8962134000.00
# 56     172457852000.00
# 57       2717325000.00
# 58       2481842865.24
# 59       4790592780.97
# 60       1890210000.00
# 61        544047000.00
# 62       1103041268.63
# 63         30687809.55
# 64        512730000.00
# 65       2841375510.40
# 66       2527130139.22
# 67       1324173531.41
# 68         94322294.58
# 69      10626015309.22
# 70       1745472000.00
# 71       3957553221.26
# 72        370743216.95
# 73      11800935863.78
# 74       2266900557.34
# 75     855746172000.00
# 76      58249521000.00
# 77    4448269160000.00
# 78       3695613957.58
# 79       7633702418.75
# 80      19968736369.05
# 81      68868160000.00
# 82         61895225.99
# 83     864032950000.00
# 84       8035718271.20
# 85        939985682.85
# 86       1430070453.06
# 87     855746172000.00
# 88       3993043287.66
# 89       3959004000.00
# 90      18130210000.00
# 91      19471313383.35
# 92     578490003800.00
# 93       4070376633.87
# 94        133012000.36
# 95      23332622689.96
# 96       5486098268.56
# 97     585230706900.00
# 98        659905869.29
# 99     786897474000.00
# 100      6460925856.08
# 101     35718615000.00
# 102        76998954.48
# 103     20576654484.82
# 104   1626806916000.00
# 105       121476057.84
# 106   3886345320000.00
# 107   3055091520000.00
# 108    104654793000.00
# 109   6028311230000.00
# 110     58455102000.00
# 111     12927550199.58
# 112      2778980000.00
# 113      6901147025.27
# 114   3729613680000.00
# 115       281601035.35
# 116     10618359000.00
# 117      9191140000.00
# 118       321610997.97
# 119     25928287499.90
# 120      3975821313.82
# 121       652880000.00
# 122     48774700000.00
# 123     33741396000.00
# 124     46788183866.66
# 125   1322667830000.00
# 126      4474118000.00
# 127    202067800000.00
# 128      2475200000.00
# 129        82142774.74
# 130        66471151.32
# 131    188346060000.00
# 132    581024316000.00
# 133    206502400000.00
# 134      2917888938.25
# 135     17473424670.63
# 136      7837479106.29
# 137      6365280000.00
# 138       208592307.69
# 139      2040585155.18
# 140     95471480000.00
# 141    324671658000.00
# 142   1848372736000.00
# 143      4989361170.86
# 144      2443339025.91
# 145    517857676000.00
# 146   3195059280000.00
# 147       553251219.54
# 148      8794463569.48
# 149       702737742.49
# 150    975951788000.00
# 151      4307814000.00
# 152       230822446.87
# 153       319130391.20
# 154    305298780000.00
# 155        52112545.69
# 156     23652311381.21
# 157       514036569.02
# 158       522529934.05
# 159     25892290957.29
# 160       667753699.05
# 161     17108400000.00
# 162     10569102055.18
# 163      9746488509.44
# 164      3204610057.38
# 165        76018001.21
# 166    816401397000.00
# 167       235857698.29
# 168    245014494400.00
# 169       380781620.76
# 170       602610523.01
# 171     43315764000.00
# 172       226563218.86
# 173         7686714.14
# 174        13054234.84
# 175     18714861000.00
# 176     15145840663.80
# 177       222094948.55
# 178       613878000.00
# 179     64091500000.00
# 180       406500365.76
# 181      2911986804.18
# 182      9773417238.41
# 183       350456197.88
# 184      3735240000.00
# 185       163103883.90
# 186       320093403.55
# 187    141356280000.00
# 188      2436474406.93
# 189     24158400000.00
# 190      7656183807.22
# 191     18861821154.28
# 192      9003007118.42
# 193       861838676.15
# 194       882636416.09
# 195      3375354562.79
# 196    388092100000.00
# 197      8153432000.00
# 198    497007818000.00
# 199       887657387.68
# 200       195559286.44
# 201     24795456000.00
# 202       154363419.39
# 203     10880345505.76
# 204      2344589747.51
# 205       769085075.04
# 206       573862287.24
# 207        10374069.29
# 208    205328340000.00
# 209     10068493947.78
# 210      1979586873.74
# 211      9993553889.99
# 212    267109350000.00
# 213     15808452000.00
# 214     48096792000.00
# 215  19983613050000.00
# 216      6808883338.15
# 217     20830680000.00
# 218               0.00
# 219    149763750000.00
# 220      1501247945.88

# %%
countryBusinessStartupPivot \
    .select("Country ISO Code", "Country Name", "GDP", "GDP Per Capita", "GNI", \
            "Startup Cost", "Startup Cost Pct of GNI", "Startup Time", "Startup Procedures", \
            "Business Regulation", "Ease of business") \
    .coalesce(1) \
    .write.csv('../output/BusinessStartupData', mode='overwrite', header='true')
